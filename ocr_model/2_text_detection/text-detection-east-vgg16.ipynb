# %%
import glob
import sys
import csv
import cv2
import time
import os
import argparse
import itertools
from multiprocessing import Pool
import threading
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
import matplotlib.patches as Patches
from shapely.geometry import Polygon

import tensorflow as tf
# Out:
# c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.4 when it was built against 1.14.2, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
print(tf.__version__)
# Out:
# 2.10.1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu,
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])  # Set your memory limit here
    except RuntimeError as e:
        print(e)

# %%
min_crop_side_ratio = 0.1
min_text_size = 10

# %%
def get_images(data_path):
  files = []
  idx = 0
  for ext in ['jpg', 'png', 'jpeg', 'JPG']:
    files.extend(glob.glob(
      os.path.join(data_path, '*.{}'.format(ext))))
    idx += 1
  return files

def get_text_file(image_file):
  txt_file = image_file.replace(os.path.basename(image_file).split('.')[1], 'txt')
  # print(txt_file)
  txt_file_name = os.path.split(txt_file)[1]
  txt_file = txt_file.replace(txt_file_name, 'gt_' + txt_file_name)
  return txt_file

def load_annotation(p):
  '''
  load annotation from the text file
  :param p:
  :return:
  '''
  text_polys = []
  text_tags = []
  if not os.path.exists(p):
    return np.array(text_polys, dtype=np.float32)
  with open(p, 'r') as f:
    reader = csv.reader(f)
    for line in reader:
      label = line[-1]
      # strip BOM. \ufeff for python3,  \xef\xbb\bf for python2
      line = [i.strip('\ufeff').strip('\xef\xbb\xbf') for i in line]

      x1, y1, x2, y2, x3, y3, x4, y4 = list(map(float, line[:8]))
      text_polys.append([[x1, y1], [x2, y2], [x3, y3], [x4, y4]])
      if label == '*' or label == '###':
        text_tags.append(True)
      else:
        text_tags.append(False)
    return np.array(text_polys, dtype=np.float32), np.array(text_tags, dtype=np.bool_)
  
def polygon_area(poly):
  '''
  compute area of a polygon
  :param poly:
  :return:
  '''
  edge = [
    (poly[1][0] - poly[0][0]) * (poly[1][1] + poly[0][1]),
    (poly[2][0] - poly[1][0]) * (poly[2][1] + poly[1][1]),
    (poly[3][0] - poly[2][0]) * (poly[3][1] + poly[2][1]),
    (poly[0][0] - poly[3][0]) * (poly[0][1] + poly[3][1])
  ]
  return np.sum(edge)/2.
  
def check_and_validate_polys(polys, tags, size):
  '''
  check so that the text poly is in the same direction,
  and also filter some invalid polygons
  :param polys:
  :param tags:
  :return:
  '''
  (h, w) = size
  if polys.shape[0] == 0:
    return polys
  polys[:, :, 0] = np.clip(polys[:, :, 0], 0, w-1)
  polys[:, :, 1] = np.clip(polys[:, :, 1], 0, h-1)

  validated_polys = []
  validated_tags = []
  for poly, tag in zip(polys, tags):
    p_area = polygon_area(poly)
    if abs(p_area) < 1:
      # print poly
      # if not FLAGS.suppress_warnings_and_error_messages:
      print('invalid poly')
      continue
    if p_area > 0:
      # if not FLAGS.suppress_warnings_and_error_messages:
      print('poly in wrong direction')
      poly = poly[(0, 3, 2, 1), :]
    validated_polys.append(poly)
    validated_tags.append(tag)
  return np.array(validated_polys), np.array(validated_tags)


def crop_area(im, polys, tags, crop_background=False, max_tries=50):
  '''
  make random crop from the input image
  :param im:
  :param polys:
  :param tags:
  :param crop_background:
  :param max_tries:
  :return:
  '''
  h, w, _ = im.shape
  pad_h = h//10
  pad_w = w//10
  h_array = np.zeros((h + pad_h*2), dtype=np.int32)
  w_array = np.zeros((w + pad_w*2), dtype=np.int32)
  for poly in polys:
    poly = np.round(poly, decimals=0).astype(np.int32)
    minx = np.min(poly[:, 0])
    maxx = np.max(poly[:, 0])
    w_array[minx+pad_w:maxx+pad_w] = 1
    miny = np.min(poly[:, 1])
    maxy = np.max(poly[:, 1])
    h_array[miny+pad_h:maxy+pad_h] = 1
  # ensure the cropped area not across a text
  h_axis = np.where(h_array == 0)[0]
  w_axis = np.where(w_array == 0)[0]
  if len(h_axis) == 0 or len(w_axis) == 0:
    return im, polys, tags
  for i in range(max_tries):
    xx = np.random.choice(w_axis, size=2)
    xmin = np.min(xx) - pad_w
    xmax = np.max(xx) - pad_w
    xmin = np.clip(xmin, 0, w-1)
    xmax = np.clip(xmax, 0, w-1)
    yy = np.random.choice(h_axis, size=2)
    ymin = np.min(yy) - pad_h
    ymax = np.max(yy) - pad_h
    ymin = np.clip(ymin, 0, h-1)
    ymax = np.clip(ymax, 0, h-1)
    if xmax - xmin < min_crop_side_ratio*w or ymax - ymin < min_crop_side_ratio*h:
      # area too small
      continue
    if polys.shape[0] != 0:
      poly_axis_in_area = (polys[:, :, 0] >= xmin) & (polys[:, :, 0] <= xmax) \
                          & (polys[:, :, 1] >= ymin) & (polys[:, :, 1] <= ymax)
      selected_polys = np.where(np.sum(poly_axis_in_area, axis=1) == 4)[0]
    else:
      selected_polys = []
    if len(selected_polys) == 0:
      # no text in this area
      if crop_background:
        return im[ymin:ymax+1, xmin:xmax+1, :], polys[selected_polys], tags[selected_polys]
      else:
        continue
    im = im[ymin:ymax+1, xmin:xmax+1, :]
    polys = polys[selected_polys]
    tags = tags[selected_polys]
    polys[:, :, 0] -= xmin
    polys[:, :, 1] -= ymin
    return im, polys, tags

  return im, polys, tags

def pad_image(img, input_size, is_train):
  new_h, new_w, _ = img.shape
  max_h_w_i = np.max([new_h, new_w, input_size])
  img_padded = np.zeros((max_h_w_i, max_h_w_i, 3), dtype=np.uint8)
  if is_train:
    shift_h = np.random.randint(max_h_w_i - new_h + 1)
    shift_w = np.random.randint(max_h_w_i - new_w + 1)
  else:
    shift_h = (max_h_w_i - new_h) // 2
    shift_w = (max_h_w_i - new_w) // 2
  img_padded[shift_h:new_h+shift_h, shift_w:new_w+shift_w, :] = img.copy()
  img = img_padded
  return img, shift_h, shift_w

def resize_image(img, text_polys, input_size, shift_h, shift_w):
  new_h, new_w, _ = img.shape
  img = cv2.resize(img, dsize=(input_size, input_size))
  # pad and resize text polygons
  resize_ratio_3_x = input_size/float(new_w)
  resize_ratio_3_y = input_size/float(new_h)
  text_polys[:, :, 0] += shift_w
  text_polys[:, :, 1] += shift_h
  text_polys[:, :, 0] *= resize_ratio_3_x
  text_polys[:, :, 1] *= resize_ratio_3_y
  return img, text_polys

def shrink_poly(poly, r):
  '''
  fit a poly inside the origin poly, maybe bugs here...
  used for generating the score map
  :param poly: the text poly
  :param r: r in the paper
  :return: the shrinked poly
  '''
  # shrink ratio
  R = 0.3
  # find the longer pair
  if np.linalg.norm(poly[0] - poly[1]) + np.linalg.norm(poly[2] - poly[3]) > \
          np.linalg.norm(poly[0] - poly[3]) + np.linalg.norm(poly[1] - poly[2]):
    # first move (p0, p1), (p2, p3), then (p0, p3), (p1, p2)
    ## p0, p1
    theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
    poly[0][0] += R * r[0] * np.cos(theta)
    poly[0][1] += R * r[0] * np.sin(theta)
    poly[1][0] -= R * r[1] * np.cos(theta)
    poly[1][1] -= R * r[1] * np.sin(theta)
    ## p2, p3
    theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
    poly[3][0] += R * r[3] * np.cos(theta)
    poly[3][1] += R * r[3] * np.sin(theta)
    poly[2][0] -= R * r[2] * np.cos(theta)
    poly[2][1] -= R * r[2] * np.sin(theta)
    ## p0, p3
    theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
    poly[0][0] += R * r[0] * np.sin(theta)
    poly[0][1] += R * r[0] * np.cos(theta)
    poly[3][0] -= R * r[3] * np.sin(theta)
    poly[3][1] -= R * r[3] * np.cos(theta)
    ## p1, p2
    theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
    poly[1][0] += R * r[1] * np.sin(theta)
    poly[1][1] += R * r[1] * np.cos(theta)
    poly[2][0] -= R * r[2] * np.sin(theta)
    poly[2][1] -= R * r[2] * np.cos(theta)
  else:
    ## p0, p3
    # print poly
    theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
    poly[0][0] += R * r[0] * np.sin(theta)
    poly[0][1] += R * r[0] * np.cos(theta)
    poly[3][0] -= R * r[3] * np.sin(theta)
    poly[3][1] -= R * r[3] * np.cos(theta)
    ## p1, p2
    theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
    poly[1][0] += R * r[1] * np.sin(theta)
    poly[1][1] += R * r[1] * np.cos(theta)
    poly[2][0] -= R * r[2] * np.sin(theta)
    poly[2][1] -= R * r[2] * np.cos(theta)
    ## p0, p1
    theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
    poly[0][0] += R * r[0] * np.cos(theta)
    poly[0][1] += R * r[0] * np.sin(theta)
    poly[1][0] -= R * r[1] * np.cos(theta)
    poly[1][1] -= R * r[1] * np.sin(theta)
    ## p2, p3
    theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
    poly[3][0] += R * r[3] * np.cos(theta)
    poly[3][1] += R * r[3] * np.sin(theta)
    poly[2][0] -= R * r[2] * np.cos(theta)
    poly[2][1] -= R * r[2] * np.sin(theta)
  return poly


def point_dist_to_line(p1, p2, p3):
  # compute the distance from p3 to p1-p2
  return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)


def fit_line(p1, p2):
  # fit a line ax+by+c = 0
  if p1[0] == p1[1]:
    return [1., 0., -p1[0]]
  else:
    [k, b] = np.polyfit(p1, p2, deg=1)
    return [k, -1., b]


def line_cross_point(line1, line2):
  # line1 0= ax+by+c, compute the cross point of line1 and line2
  if line1[0] != 0 and line1[0] == line2[0]:
    # if not FLAGS.suppress_warnings_and_error_messages:
    print('Cross point does not exist')
    return None
  if line1[0] == 0 and line2[0] == 0:
    # if not FLAGS.suppress_warnings_and_error_messages:
    print('Cross point does not exist')
    return None
  if line1[1] == 0:
    x = -line1[2]
    y = line2[0] * x + line2[2]
  elif line2[1] == 0:
    x = -line2[2]
    y = line1[0] * x + line1[2]
  else:
    k1, _, b1 = line1
    k2, _, b2 = line2
    x = -(b1-b2)/(k1-k2)
    y = k1*x + b1
  return np.array([x, y], dtype=np.float32)


def line_verticle(line, point):
  # get the verticle line from line across point
  if line[1] == 0:
    verticle = [0, -1, point[1]]
  else:
    if line[0] == 0:
      verticle = [1, 0, -point[0]]
    else:
      verticle = [-1./line[0], -1, point[1] - (-1/line[0] * point[0])]
  return verticle


def rectangle_from_parallelogram(poly):
  '''
  fit a rectangle from a parallelogram
  :param poly:
  :return:
  '''
  p0, p1, p2, p3 = poly
  angle_p0 = np.arccos(np.dot(p1-p0, p3-p0)/(np.linalg.norm(p0-p1) * np.linalg.norm(p3-p0)))
  if angle_p0 < 0.5 * np.pi:
    if np.linalg.norm(p0 - p1) > np.linalg.norm(p0-p3):
      # p0 and p2
      ## p0
      p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
      p2p3_verticle = line_verticle(p2p3, p0)

      new_p3 = line_cross_point(p2p3, p2p3_verticle)
      ## p2
      p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
      p0p1_verticle = line_verticle(p0p1, p2)

      new_p1 = line_cross_point(p0p1, p0p1_verticle)
      return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
    else:
      p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
      p1p2_verticle = line_verticle(p1p2, p0)

      new_p1 = line_cross_point(p1p2, p1p2_verticle)
      p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
      p0p3_verticle = line_verticle(p0p3, p2)

      new_p3 = line_cross_point(p0p3, p0p3_verticle)
      return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
  else:
    if np.linalg.norm(p0-p1) > np.linalg.norm(p0-p3):
      # p1 and p3
      ## p1
      p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
      p2p3_verticle = line_verticle(p2p3, p1)

      new_p2 = line_cross_point(p2p3, p2p3_verticle)
      ## p3
      p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
      p0p1_verticle = line_verticle(p0p1, p3)

      new_p0 = line_cross_point(p0p1, p0p1_verticle)
      return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)
    else:
      p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
      p0p3_verticle = line_verticle(p0p3, p1)

      new_p0 = line_cross_point(p0p3, p0p3_verticle)
      p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
      p1p2_verticle = line_verticle(p1p2, p3)

      new_p2 = line_cross_point(p1p2, p1p2_verticle)
      return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)


def sort_rectangle(poly):
  # sort the four coordinates of the polygon, points in poly should be sorted clockwise
  # First find the lowest point
  p_lowest = np.argmax(poly[:, 1])
  if np.count_nonzero(poly[:, 1] == poly[p_lowest, 1]) == 2:
    # if the bottom line is parallel to x-axis, then p0 must be the upper-left corner
    p0_index = np.argmin(np.sum(poly, axis=1))
    p1_index = (p0_index + 1) % 4
    p2_index = (p0_index + 2) % 4
    p3_index = (p0_index + 3) % 4
    return poly[[p0_index, p1_index, p2_index, p3_index]], 0.
  else:
    # find the point that sits right to the lowest point
    p_lowest_right = (p_lowest - 1) % 4
    p_lowest_left = (p_lowest + 1) % 4
    angle = np.arctan(-(poly[p_lowest][1] - poly[p_lowest_right][1])/(poly[p_lowest][0] - poly[p_lowest_right][0]))
    # assert angle > 0
    if angle <= 0:
      # if not FLAGS.suppress_warnings_and_error_messages:
        print(angle, poly[p_lowest], poly[p_lowest_right])
    if angle/np.pi * 180 > 45:
      #  this point is p2
      p2_index = p_lowest
      p1_index = (p2_index - 1) % 4
      p0_index = (p2_index - 2) % 4
      p3_index = (p2_index + 1) % 4
      return poly[[p0_index, p1_index, p2_index, p3_index]], -(np.pi/2 - angle)
    else:
      #  this point is p3
      p3_index = p_lowest
      p0_index = (p3_index + 1) % 4
      p1_index = (p3_index + 2) % 4
      p2_index = (p3_index + 3) % 4
      return poly[[p0_index, p1_index, p2_index, p3_index]], angle


def restore_rectangle_rbox(origin, geometry):
  d = geometry[:, :4]
  angle = geometry[:, 4]
  # for angle > 0
  origin_0 = origin[angle >= 0]
  d_0 = d[angle >= 0]
  angle_0 = angle[angle >= 0]
  if origin_0.shape[0] > 0:
    p = np.array([np.zeros(d_0.shape[0]), -d_0[:, 0] - d_0[:, 2],
                  d_0[:, 1] + d_0[:, 3], -d_0[:, 0] - d_0[:, 2],
                  d_0[:, 1] + d_0[:, 3], np.zeros(d_0.shape[0]),
                  np.zeros(d_0.shape[0]), np.zeros(d_0.shape[0]),
                  d_0[:, 3], -d_0[:, 2]])
    p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

    rotate_matrix_x = np.array([np.cos(angle_0), np.sin(angle_0)]).transpose((1, 0))
    rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

    rotate_matrix_y = np.array([-np.sin(angle_0), np.cos(angle_0)]).transpose((1, 0))
    rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

    p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
    p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

    p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

    p3_in_origin = origin_0 - p_rotate[:, 4, :]
    new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
    new_p1 = p_rotate[:, 1, :] + p3_in_origin
    new_p2 = p_rotate[:, 2, :] + p3_in_origin
    new_p3 = p_rotate[:, 3, :] + p3_in_origin

    new_p_0 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                              new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
  else:
    new_p_0 = np.zeros((0, 4, 2))
  # for angle < 0
  origin_1 = origin[angle < 0]
  d_1 = d[angle < 0]
  angle_1 = angle[angle < 0]
  if origin_1.shape[0] > 0:
    p = np.array([-d_1[:, 1] - d_1[:, 3], -d_1[:, 0] - d_1[:, 2],
                  np.zeros(d_1.shape[0]), -d_1[:, 0] - d_1[:, 2],
                  np.zeros(d_1.shape[0]), np.zeros(d_1.shape[0]),
                  -d_1[:, 1] - d_1[:, 3], np.zeros(d_1.shape[0]),
                  -d_1[:, 1], -d_1[:, 2]])
    p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

    rotate_matrix_x = np.array([np.cos(-angle_1), -np.sin(-angle_1)]).transpose((1, 0))
    rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

    rotate_matrix_y = np.array([np.sin(-angle_1), np.cos(-angle_1)]).transpose((1, 0))
    rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

    p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
    p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

    p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

    p3_in_origin = origin_1 - p_rotate[:, 4, :]
    new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
    new_p1 = p_rotate[:, 1, :] + p3_in_origin
    new_p2 = p_rotate[:, 2, :] + p3_in_origin
    new_p3 = p_rotate[:, 3, :] + p3_in_origin

    new_p_1 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                              new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
  else:
    new_p_1 = np.zeros((0, 4, 2))
  return np.concatenate([new_p_0, new_p_1])


def restore_rectangle(origin, geometry):
  return restore_rectangle_rbox(origin, geometry)

def generate_rbox(im_size, polys, tags, geometry=None):
  h, w = im_size
  shrinked_poly_mask = np.zeros((h, w), dtype=np.uint8)
  orig_poly_mask = np.zeros((h, w), dtype=np.uint8)
  score_map = np.zeros((h, w), dtype=np.uint8)
  geo_map = np.zeros((h, w, 5), dtype=np.float32)
  # mask used during traning, to ignore some hard areas
  overly_small_text_region_training_mask = np.ones((h, w), dtype=np.uint8)
  for poly_idx, poly_data in enumerate(zip(polys, tags)):
    poly = poly_data[0]
    tag = poly_data[1]

    r = [None, None, None, None]
    for i in range(4):
      r[i] = min(np.linalg.norm(poly[i] - poly[(i + 1) % 4]),
                 np.linalg.norm(poly[i] - poly[(i - 1) % 4]))
    # score map
    shrinked_poly = shrink_poly(poly.copy(), r).astype(np.int32)[np.newaxis, :, :]
    cv2.fillPoly(score_map, shrinked_poly, 1)
    cv2.fillPoly(shrinked_poly_mask, shrinked_poly, poly_idx + 1)
    cv2.fillPoly(orig_poly_mask, poly.astype(np.int32)[np.newaxis, :, :], 1)
    # if the poly is too small, then ignore it during training
    poly_h = min(np.linalg.norm(poly[0] - poly[3]), np.linalg.norm(poly[1] - poly[2]))
    poly_w = min(np.linalg.norm(poly[0] - poly[1]), np.linalg.norm(poly[2] - poly[3]))
    if min(poly_h, poly_w) < min_text_size:
      cv2.fillPoly(overly_small_text_region_training_mask, poly.astype(np.int32)[np.newaxis, :, :], 0)
    if tag:
      cv2.fillPoly(overly_small_text_region_training_mask, poly.astype(np.int32)[np.newaxis, :, :], 0)

    xy_in_poly = np.argwhere(shrinked_poly_mask == (poly_idx + 1))
    # if geometry == 'RBOX':
    # generate a parallelogram for any combination of two vertices
    fitted_parallelograms = []
    for i in range(4):
      p0 = poly[i]
      p1 = poly[(i + 1) % 4]
      p2 = poly[(i + 2) % 4]
      p3 = poly[(i + 3) % 4]
      edge = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
      backward_edge = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
      forward_edge = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
      if point_dist_to_line(p0, p1, p2) > point_dist_to_line(p0, p1, p3):
        # parallel lines through p2
        if edge[1] == 0:
          edge_opposite = [1, 0, -p2[0]]
        else:
          edge_opposite = [edge[0], -1, p2[1] - edge[0] * p2[0]]
      else:
        # after p3
        if edge[1] == 0:
          edge_opposite = [1, 0, -p3[0]]
        else:
          edge_opposite = [edge[0], -1, p3[1] - edge[0] * p3[0]]
      # move forward edge
      new_p0 = p0
      new_p1 = p1
      new_p2 = p2
      new_p3 = p3
      new_p2 = line_cross_point(forward_edge, edge_opposite)
      if point_dist_to_line(p1, new_p2, p0) > point_dist_to_line(p1, new_p2, p3):
        # across p0
        if forward_edge[1] == 0:
          forward_opposite = [1, 0, -p0[0]]
        else:
          forward_opposite = [forward_edge[0], -1, p0[1] - forward_edge[0] * p0[0]]
      else:
        # across p3
        if forward_edge[1] == 0:
          forward_opposite = [1, 0, -p3[0]]
        else:
          forward_opposite = [forward_edge[0], -1, p3[1] - forward_edge[0] * p3[0]]
      new_p0 = line_cross_point(forward_opposite, edge)
      new_p3 = line_cross_point(forward_opposite, edge_opposite)
      fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
      # or move backward edge
      new_p0 = p0
      new_p1 = p1
      new_p2 = p2
      new_p3 = p3
      new_p3 = line_cross_point(backward_edge, edge_opposite)
      if point_dist_to_line(p0, p3, p1) > point_dist_to_line(p0, p3, p2):
        # across p1
        if backward_edge[1] == 0:
          backward_opposite = [1, 0, -p1[0]]
        else:
          backward_opposite = [backward_edge[0], -1, p1[1] - backward_edge[0] * p1[0]]
      else:
        # across p2
        if backward_edge[1] == 0:
          backward_opposite = [1, 0, -p2[0]]
        else:
          backward_opposite = [backward_edge[0], -1, p2[1] - backward_edge[0] * p2[0]]
      new_p1 = line_cross_point(backward_opposite, edge)
      new_p2 = line_cross_point(backward_opposite, edge_opposite)
      fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
    areas = [Polygon(t).area for t in fitted_parallelograms]
    parallelogram = np.array(fitted_parallelograms[np.argmin(areas)][:-1], dtype=np.float32)
    # sort thie polygon
    parallelogram_coord_sum = np.sum(parallelogram, axis=1)
    min_coord_idx = np.argmin(parallelogram_coord_sum)
    parallelogram = parallelogram[
      [min_coord_idx, (min_coord_idx + 1) % 4, (min_coord_idx + 2) % 4, (min_coord_idx + 3) % 4]]

    rectange = rectangle_from_parallelogram(parallelogram)
    rectange, rotate_angle = sort_rectangle(rectange)

    p0_rect, p1_rect, p2_rect, p3_rect = rectange
    for y, x in xy_in_poly:
      point = np.array([x, y], dtype=np.float32)
      # top
      geo_map[y, x, 0] = point_dist_to_line(p0_rect, p1_rect, point)
      # right
      geo_map[y, x, 1] = point_dist_to_line(p1_rect, p2_rect, point)
      # down
      geo_map[y, x, 2] = point_dist_to_line(p2_rect, p3_rect, point)
      # left
      geo_map[y, x, 3] = point_dist_to_line(p3_rect, p0_rect, point)
      # angle
      geo_map[y, x, 4] = rotate_angle

  shrinked_poly_mask = (shrinked_poly_mask > 0).astype('uint8')
  text_region_boundary_training_mask = 1 - (orig_poly_mask - shrinked_poly_mask)

  return score_map, geo_map, overly_small_text_region_training_mask, text_region_boundary_training_mask

# %%
class threadsafe_iter:
  """Takes an iterator/generator and makes it thread-safe by
  serializing call to the `next` method of given iterator/generator.
  """
  def __init__(self, it):
    self.it = it
    self.lock = threading.Lock()

  def __iter__(self):
    return self

  def __next__(self): # Python 3
    with self.lock:
      return next(self.it)

  def next(self): # Python 2
    with self.lock:
      return self.it.next()
    
def threadsafe_generator(f):
  """A decorator that takes a generator function and makes it thread-safe.
  """
  def g(*a, **kw):
    return threadsafe_iter(f(*a, **kw))
  return g

def threadsafe_generator(f):
  """A decorator that takes a generator function and makes it thread-safe.
  """
  def g(*a, **kw):
    return threadsafe_iter(f(*a, **kw))
  return g

@threadsafe_generator
def generator(
    training_data_path,
    batch_size=32,
    input_size=512,
    background_ratio=3./8,
    is_train=True,
    random_scale=np.array([0.5, 1, 2.0, 3.0]),
    geometry="RBOX",
    suppress_warnings=False,
    vis=False,
    idx=None
):
    """
    Data generator for text detection training.

    Args:
        training_data_path (str): Path to the training images.
        batch_size (int): Number of samples per batch.
        input_size (int): Input size for the model (e.g., 512).
        background_ratio (float): Ratio of background cropping.
        is_train (bool): Whether this is for training or not.
        random_scale (np.array): Random scaling factors for augmentation.
        geometry (str): Geometry type for text detection ('RBOX' or 'QUAD').
        suppress_warnings (bool): If True, suppress warning messages.
        vis (bool): If True, visualize intermediate results.
        idx (list): Indices of images to include (optional).

    Yields:
        Tuple: A batch of preprocessed images and corresponding labels.
    """
    # Get image list
    image_list = np.array(get_images(training_data_path))
    if idx is not None:
        image_list = image_list[idx]
    print(f"{image_list.shape[0]} training images in {training_data_path}")

    index = np.arange(0, image_list.shape[0])
    epoch = 1

    while True:
        np.random.shuffle(index)
        images = []
        image_fns = []
        score_maps = []
        geo_maps = []
        overly_small_text_region_training_masks = []
        text_region_boundary_training_masks = []

        for i in index:
            try:                
                im_fn = image_list[i]
                # print(im_fn)
                im = cv2.imread(im_fn)
                h, w, _ = im.shape

                txt_fn = get_text_file(im_fn)
                if not os.path.exists(txt_fn):
                    if not suppress_warnings:
                        print(f"Text file {txt_fn} does not exist")
                    continue

                text_polys, text_tags = load_annotation(txt_fn)
                text_polys, text_tags = check_and_validate_polys(text_polys, text_tags, (h, w))

                # Random scale
                rd_scale = np.random.choice(random_scale)
                x_scale_variation = np.random.randint(-10, 10) / 100.
                y_scale_variation = np.random.randint(-10, 10) / 100.
                im = cv2.resize(im, dsize=None, fx=rd_scale + x_scale_variation, fy=rd_scale + y_scale_variation)
                text_polys[:, :, 0] *= rd_scale + x_scale_variation
                text_polys[:, :, 1] *= rd_scale + y_scale_variation

                # Random crop
                if np.random.rand() < background_ratio:
                    # Crop background
                    im, text_polys, text_tags = crop_area(im, text_polys, text_tags, crop_background=True)
                    if text_polys.shape[0] > 0:
                        continue
                    # Pad and resize
                    im, _, _ = pad_image(im, input_size, is_train)
                    im = cv2.resize(im, dsize=(input_size, input_size))
                    score_map = np.zeros((input_size, input_size), dtype=np.uint8)
                    geo_map_channels = 5 if geometry == 'RBOX' else 8
                    geo_map = np.zeros((input_size, input_size, geo_map_channels), dtype=np.float32)
                    overly_small_text_region_training_mask = np.ones((input_size, input_size), dtype=np.uint8)
                    text_region_boundary_training_mask = np.ones((input_size, input_size), dtype=np.uint8)
                else:
                    im, text_polys, text_tags = crop_area(im, text_polys, text_tags, crop_background=False)
                    if text_polys.shape[0] == 0:
                        continue
                    h, w, _ = im.shape
                    im, shift_h, shift_w = pad_image(im, input_size, is_train)
                    im, text_polys = resize_image(im, text_polys, input_size, shift_h, shift_w)
                    new_h, new_w, _ = im.shape
                    score_map, geo_map, overly_small_text_region_training_mask, text_region_boundary_training_mask = generate_rbox((new_h, new_w), text_polys, text_tags, geometry)

                if vis:
                    # Visualization for debugging
                    fig, axs = plt.subplots(2, 2, figsize=(8, 8))
                    axs[0, 0].imshow(im[:, :, ::-1])
                    axs[0, 0].set_xticks([])
                    axs[0, 0].set_yticks([])
                    for poly in text_polys:
                        poly_h = min(abs(poly[3, 1] - poly[0, 1]), abs(poly[2, 1] - poly[1, 1]))
                        poly_w = min(abs(poly[1, 0] - poly[0, 0]), abs(poly[2, 0] - poly[3, 0]))
                        axs[0, 0].add_artist(Patches.Polygon(
                        poly, facecolor='none', edgecolor='green', linewidth=2, linestyle='-', fill=True))
                        axs[0, 0].text(poly[0, 0], poly[0, 1], '{:.0f}-{:.0f}'.format(poly_h, poly_w), color='purple')
                    axs[0, 1].imshow(score_map[::, ::])
                    axs[0, 1].set_xticks([])
                    axs[0, 1].set_yticks([])
                    axs[1, 0].imshow(geo_map[::, ::, 0])
                    axs[1, 0].set_xticks([])
                    axs[1, 0].set_yticks([])
                    axs[1, 1].imshow(geo_map[::, ::, 1])
                    axs[1, 1].set_xticks([])
                    axs[1, 1].set_yticks([])
                    # axs[2, 0].imshow(geo_map[::, ::, 2])
                    # axs[2, 0].set_xticks([])
                    # axs[2, 0].set_yticks([])
                    # # axs[2, 1].imshow(training_mask[::, ::])
                    # axs[2, 1].set_xticks([])
                    # axs[2, 1].set_yticks([])
                    plt.tight_layout()
                    plt.show()
                    plt.close()


                # Normalize and append data
                im = (im / 127.5) - 1.
                images.append(im[:, :, ::-1].astype(np.float32))
                image_fns.append(im_fn)
                score_maps.append(score_map[::4, ::4, np.newaxis].astype(np.float32))
                geo_maps.append(geo_map[::4, ::4, :].astype(np.float32))
                overly_small_text_region_training_masks.append(overly_small_text_region_training_mask[::4, ::4, np.newaxis].astype(np.float32))
                text_region_boundary_training_masks.append(text_region_boundary_training_mask[::4, ::4, np.newaxis].astype(np.float32))

                if len(images) == batch_size:
                    yield [np.array(images),
                           np.array(overly_small_text_region_training_masks),
                           np.array(text_region_boundary_training_masks),
                           np.array(score_maps)], [np.array(score_maps), np.array(geo_maps)]
                    images = []
                    image_fns = []
                    score_maps = []
                    geo_maps = []
                    overly_small_text_region_training_masks = []
                    text_region_boundary_training_masks = []

            except Exception as e:
                # if not suppress_warnings:
                print(f"Error processing image {im_fn}: {str(e)}")
                continue

        epoch += 1

# %%
generator_instance = generator(
    training_data_path="../data/mixed-datasets/train_data",
    batch_size=4,
    input_size=512,
    background_ratio=0.375,
    is_train=True,
    random_scale=np.array([1, 1.5, 2]),
    geometry="RBOX",
    suppress_warnings=True,
    vis=True
)

# %%
[input_images, overly_small_text_region_training_masks, text_region_boundary_training_masks, score_maps], \
    [target_score_maps, target_geo_maps] = next(generator_instance)
# Out:
# 5582 training images in ../data/mixed-datasets/train_data

# %% [markdown]
# # Model Training

# %%
# vgg16_test = tf.keras.applications.VGG16(weights='imagenet', include_top=False, pooling=None)
# vgg16_test.summary()

# %%
RESIZE_FACTOR = 2

def resize_bilinear(x):
  return tf.image.resize(x, size=[tf.shape(x)[1] * RESIZE_FACTOR, tf.shape(x)[2] * RESIZE_FACTOR], method=tf.image.ResizeMethod.BILINEAR)

def resize_output_shape(input_shape):
  shape = list(input_shape)
  assert len(shape) == 4
  shape[1] *= RESIZE_FACTOR
  shape[2] *= RESIZE_FACTOR
  return tuple(shape)

class EAST_model(tf.keras.Model):
  def __init__(self, input_size=512):
    super(EAST_model, self).__init__()

    input_image = tf.keras.layers.Input(shape=(None, None, 3), name='input_image')
    overly_small_text_region_training_mask = tf.keras.layers.Input(shape=(None, None, 1), name='overly_small_text_region_training_mask')
    text_region_boundary_training_mask = tf.keras.layers.Input(shape=(None, None, 1), name='text_region_boundary_training_mask')
    target_score_map = tf.keras.layers.Input(shape=(None, None, 1), name='target_score_map')
    vgg16 = tf.keras.applications.VGG16(input_tensor=input_image, weights='imagenet', include_top=False, pooling=None)
    x = vgg16.get_layer('block5_pool').output
    # x = tf.keras.layers.Conv2D(160, (1, 1), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    # x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    x = tf.keras.layers.Lambda(resize_bilinear, name='resize_1')(x)
    x = tf.keras.layers.concatenate([x, vgg16.get_layer('block4_pool').output], axis=3)
    x = tf.keras.layers.Conv2D(128, (1, 1), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(128, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Lambda(resize_bilinear, name='resize_2')(x)
    x = tf.keras.layers.concatenate([x, vgg16.get_layer('block3_pool').output], axis=3)
    x = tf.keras.layers.Conv2D(64, (1, 1), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Lambda(resize_bilinear, name='resize_3')(x)
    x = tf.keras.layers.concatenate([x, vgg16.get_layer('block2_pool').output], axis=3)
    x = tf.keras.layers.Conv2D(32, (1, 1), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(32, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)

    # x = tf.keras.layers.UpSampling2D(size=(2,2))(x)

    x = tf.keras.layers.Conv2D(32, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.997, epsilon=1e-5, scale=True)(x)
    x = tf.keras.layers.Activation('relu')(x)

    pred_score_map = tf.keras.layers.Conv2D(1, (1, 1), activation="sigmoid", name='pred_score_map')(x)
    rbox_geo_map = tf.keras.layers.Conv2D(4, (1, 1), activation="sigmoid", name='rbox_geo_map')(x)
    rbox_geo_map = tf.keras.layers.Lambda(lambda x: x * input_size)(rbox_geo_map)
    angle_map = tf.keras.layers.Conv2D(1, (1, 1), activation="sigmoid", name='rbox_angle_map')(x)
    angle_map = tf.keras.layers.Lambda(lambda x: (x - 0.5) * np.pi / 2)(angle_map)
    pred_geo_map = tf.keras.layers.concatenate([rbox_geo_map, angle_map], axis=3, name='pred_geo_map')

    model = tf.keras.models.Model(inputs=[input_image], outputs=[pred_score_map, pred_geo_map], name='east-vgg16')

    self.model = model
    self.input_image = input_image
    self.overly_small_text_region_training_mask = overly_small_text_region_training_mask
    self.text_region_boundary_training_mask = text_region_boundary_training_mask
    self.target_score_map = target_score_map
    self.pred_score_map = pred_score_map
    self.pred_geo_map = pred_geo_map

  def call(self, x):
    return self.model(x)

# %%
input_size = 512

east = EAST_model(input_size)
east.model.summary()
# Out:
# Model: "east-vgg16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, None, None,  0           []
#                                  3)]
#
#  block1_conv1 (Conv2D)          (None, None, None,   1792        ['input_image[0][0]']
#                                 64)
#
#  block1_conv2 (Conv2D)          (None, None, None,   36928       ['block1_conv1[0][0]']
#                                 64)
#
#  block1_pool (MaxPooling2D)     (None, None, None,   0           ['block1_conv2[0][0]']
#                                 64)
#
#  block2_conv1 (Conv2D)          (None, None, None,   73856       ['block1_pool[0][0]']
#                                 128)
#
#  block2_conv2 (Conv2D)          (None, None, None,   147584      ['block2_conv1[0][0]']
#                                 128)
#
#  block2_pool (MaxPooling2D)     (None, None, None,   0           ['block2_conv2[0][0]']
#                                 128)
#
#  block3_conv1 (Conv2D)          (None, None, None,   295168      ['block2_pool[0][0]']
#                                 256)
#
#  block3_conv2 (Conv2D)          (None, None, None,   590080      ['block3_conv1[0][0]']
#                                 256)
#
#  block3_conv3 (Conv2D)          (None, None, None,   590080      ['block3_conv2[0][0]']
#                                 256)
#
#  block3_pool (MaxPooling2D)     (None, None, None,   0           ['block3_conv3[0][0]']
#                                 256)
#
#  block4_conv1 (Conv2D)          (None, None, None,   1180160     ['block3_pool[0][0]']
#                                 512)
#
#  block4_conv2 (Conv2D)          (None, None, None,   2359808     ['block4_conv1[0][0]']
#                                 512)
#
#  block4_conv3 (Conv2D)          (None, None, None,   2359808     ['block4_conv2[0][0]']
#                                 512)
#
#  block4_pool (MaxPooling2D)     (None, None, None,   0           ['block4_conv3[0][0]']
#                                 512)
#
#  block5_conv1 (Conv2D)          (None, None, None,   2359808     ['block4_pool[0][0]']
#                                 512)
#
#  block5_conv2 (Conv2D)          (None, None, None,   2359808     ['block5_conv1[0][0]']
#                                 512)
#
#  block5_conv3 (Conv2D)          (None, None, None,   2359808     ['block5_conv2[0][0]']
#                                 512)
#
#  block5_pool (MaxPooling2D)     (None, None, None,   0           ['block5_conv3[0][0]']
#                                 512)
#
#  resize_1 (Lambda)              (None, None, None,   0           ['block5_pool[0][0]']
#                                 512)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['resize_1[0][0]',
#                                 1024)                             'block4_pool[0][0]']
#
#  conv2d (Conv2D)                (None, None, None,   131200      ['concatenate[0][0]']
#                                 128)
#
#  batch_normalization (BatchNorm  (None, None, None,   512        ['conv2d[0][0]']
#  alization)                     128)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 128)
#
#  conv2d_1 (Conv2D)              (None, None, None,   147584      ['activation[0][0]']
#                                 128)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   512        ['conv2d_1[0][0]']
#  rmalization)                   128)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 128)
#
#  resize_2 (Lambda)              (None, None, None,   0           ['activation_1[0][0]']
#                                 128)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['resize_2[0][0]',
#                                 384)                              'block3_pool[0][0]']
#
#  conv2d_2 (Conv2D)              (None, None, None,   24640       ['concatenate_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   256        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   36928       ['activation_2[0][0]']
#                                 64)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   256        ['conv2d_3[0][0]']
#  rmalization)                   64)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 64)
#
#  resize_3 (Lambda)              (None, None, None,   0           ['activation_3[0][0]']
#                                 64)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['resize_3[0][0]',
#                                 192)                              'block2_pool[0][0]']
#
#  conv2d_4 (Conv2D)              (None, None, None,   6176        ['concatenate_2[0][0]']
#                                 32)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   128        ['conv2d_4[0][0]']
#  rmalization)                   32)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 32)
#
#  conv2d_5 (Conv2D)              (None, None, None,   9248        ['activation_4[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   128        ['conv2d_5[0][0]']
#  rmalization)                   32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 32)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9248        ['activation_5[0][0]']
#                                 32)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   128        ['conv2d_6[0][0]']
#  rmalization)                   32)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 32)
#
#  rbox_geo_map (Conv2D)          (None, None, None,   132         ['activation_6[0][0]']
#                                 4)
#
#  rbox_angle_map (Conv2D)        (None, None, None,   33          ['activation_6[0][0]']
#                                 1)
#
#  lambda (Lambda)                (None, None, None,   0           ['rbox_geo_map[0][0]']
#                                 4)
#
#  lambda_1 (Lambda)              (None, None, None,   0           ['rbox_angle_map[0][0]']
#                                 1)
#
#  pred_score_map (Conv2D)        (None, None, None,   33          ['activation_6[0][0]']
#                                 1)
#
#  pred_geo_map (Concatenate)     (None, None, None,   0           ['lambda[0][0]',
#                                 5)                                'lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 15,081,830
# Trainable params: 15,080,870
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
# tf.keras.utils.plot_model(east.model, to_file='east-vgg16.png', show_shapes=True, show_layer_names=True)

# %%
def dice_loss(overly_small_text_region_training_mask, text_region_boundary_training_mask, loss_weight, small_text_weight, score_y_true, score_y_pred):
  eps = 1e-5
  _training_mask = tf.minimum(overly_small_text_region_training_mask + small_text_weight, 1) * text_region_boundary_training_mask
  intersection = tf.reduce_sum(score_y_true * score_y_pred * _training_mask)
  union = tf.reduce_sum(score_y_true * _training_mask) + tf.reduce_sum(score_y_pred * _training_mask) + eps
  loss = 1. - (2. * intersection / union)

  return loss * loss_weight

def rbox_loss(overly_small_text_region_training_mask, text_region_boundary_training_mask, small_text_weight, target_score_map, geo_y_true, geo_y_pred):
  # d1 -> top, d2->right, d3->bottom, d4->left
  d1_gt, d2_gt, d3_gt, d4_gt, theta_gt = tf.split(value=geo_y_true, num_or_size_splits=5, axis=3)
  d1_pred, d2_pred, d3_pred, d4_pred, theta_pred = tf.split(value=geo_y_pred, num_or_size_splits=5, axis=3)
  area_gt = (d1_gt + d3_gt) * (d2_gt + d4_gt)
  area_pred = (d1_pred + d3_pred) * (d2_pred + d4_pred)
  w_union = tf.minimum(d2_gt, d2_pred) + tf.minimum(d4_gt, d4_pred)
  h_union = tf.minimum(d1_gt, d1_pred) + tf.minimum(d3_gt, d3_pred)
  area_intersect = w_union * h_union
  area_union = area_gt + area_pred - area_intersect
  L_AABB = -tf.math.log((area_intersect + 1.0) / (area_union + 1.0))
  L_theta = 1 - tf.cos(theta_pred - theta_gt)
  L_g = L_AABB + 20 * L_theta
  _training_mask = tf.minimum(overly_small_text_region_training_mask + small_text_weight, 1) * text_region_boundary_training_mask

  return tf.reduce_mean(L_g * target_score_map * _training_mask)

# %%
score_map_loss_weight = tf.Variable(0.01, name='score_map_loss_weight')
small_text_weight = tf.Variable(0., name='small_text_weight')

# %%
init_learning_rate = 0.0001
lr_decay_rate = 0.94
lr_decay_steps = 16250


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    init_learning_rate,
    decay_steps=lr_decay_steps,
    decay_rate=lr_decay_rate,
    staircase=True)

optimizers = tf.optimizers.Adam(lr_schedule)

# %%
@tf.function
def train_step(model,
               x,
               optimizer,
               overly_small_text_region_training_mask,
               text_region_boundary_training_mask,
               small_text_weight,
               target_score_map,
               target_geo_maps, loss_weight):
  with tf.GradientTape() as tape:
    score_y_pred, geo_y_pred = model(x)
    _dice_loss = dice_loss(overly_small_text_region_training_mask, text_region_boundary_training_mask, loss_weight, small_text_weight, target_score_map, score_y_pred)
    _rbox_loss = rbox_loss(overly_small_text_region_training_mask, text_region_boundary_training_mask, small_text_weight, target_score_map, target_geo_maps, geo_y_pred)
    loss = _dice_loss + _rbox_loss

  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
checkpoint_path = "../models/east_vgg16_rbox_06-12-23-00"
save_checkpoint_steps = 100

ckpt = tf.train.Checkpoint(step=tf.Variable(0), model=east)
ckpt_manager = tf.train.CheckpointManager(ckpt, directory=checkpoint_path, max_to_keep=5)
latest_ckpt = tf.train.latest_checkpoint(checkpoint_path)

# restore latest checkpoint
if latest_ckpt:
    ckpt.restore(latest_ckpt)
    print('global_step : {}, checkpoint is restored!'.format(int(ckpt.step)))

# set tensorboard summary writer
summary_writer = tf.summary.create_file_writer(checkpoint_path + '/train')

# %%
train_data_generator = generator(
    training_data_path="../data/mixed-datasets/train_data",
    batch_size=8,
    input_size=512,
    background_ratio=0.375,
    is_train=True,
    random_scale=np.array([0.75, 1, 1.5]),
    geometry="RBOX",
    suppress_warnings=True,
    vis=False
)

# %%
max_steps = 12000

while int(ckpt.step) < (max_steps + 1):
    # load data
    [input_images, overly_small_text_region_training_masks, text_region_boundary_training_masks, score_maps], \
    [target_score_maps, target_geo_maps] = next(train_data_generator)

    # update parameter
    train_step(east,
                input_images,
                optimizers,
                overly_small_text_region_training_masks,
                text_region_boundary_training_masks,
                small_text_weight,
                target_score_maps,
                target_geo_maps,
                score_map_loss_weight
                )

    score_y_pred, geo_y_pred = east(input_images)
    _dice_loss = dice_loss(overly_small_text_region_training_masks, text_region_boundary_training_masks, score_map_loss_weight,
                            small_text_weight, target_score_maps, score_y_pred)
    _rbox_loss = rbox_loss(overly_small_text_region_training_masks, text_region_boundary_training_masks,
                            small_text_weight, target_score_maps, target_geo_maps, geo_y_pred)
    loss = _dice_loss + _rbox_loss

    print('Step {:06d}, dice_loss {:.4f}, rbox_loss {:.4f}, total_loss {:.4f}'.format(int(ckpt.step), _dice_loss, _rbox_loss, loss))

    if ckpt.step % save_checkpoint_steps == 0:
        # save checkpoint
        ckpt_manager.save(checkpoint_number=ckpt.step)
        print('global_step : {}, checkpoint is saved!'.format(int(ckpt.step)))

        with summary_writer.as_default():
            tf.summary.scalar('loss', loss, step=int(ckpt.step))
            tf.summary.scalar('pred_score_map_loss', _dice_loss, step=int(ckpt.step))
            tf.summary.scalar('pred_geo_map_loss ', _rbox_loss, step=int(ckpt.step))
            tf.summary.scalar('learning_rate ', optimizers.lr(ckpt.step).numpy(), step=int(ckpt.step))
            tf.summary.scalar('small_text_weight', small_text_weight, step=int(ckpt.step))

            tf.summary.image("input_image", tf.cast((input_images + 1) * 127.5, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("overly_small_text_region_training_mask", tf.cast(overly_small_text_region_training_masks * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("text_region_boundary_training_mask", tf.cast(text_region_boundary_training_masks * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("score_map_target", tf.cast(target_score_maps * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("score_map_pred", tf.cast(score_y_pred * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
            for i in range(4):
                tf.summary.image("geo_map_%d_target" % (i), tf.cast(tf.expand_dims(target_geo_maps[:, :, :, i], axis=3) / input_size * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
                tf.summary.image("geo_map_%d_pred" % (i), tf.cast(tf.expand_dims(geo_y_pred[:, :, :, i], axis=3) / input_size * 255, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("geo_map_4_target", tf.cast((tf.expand_dims(target_geo_maps[:, :, :, 4], axis=3) + 1) * 127.5, tf.uint8), step=int(ckpt.step), max_outputs=3)
            tf.summary.image("geo_map_4_pred", tf.cast((tf.expand_dims(geo_y_pred[:, :, :, 4], axis=3) + 1) * 127.5, tf.uint8), step=int(ckpt.step), max_outputs=3)

    ckpt.step.assign_add(1)
# Out:
# 5582 training images in ../data/mixed-datasets/train_data
# Step 000000, dice_loss 0.0098, rbox_loss 0.1022, total_loss 0.1120
# global_step : 0, checkpoint is saved!
# Step 000001, dice_loss 0.0098, rbox_loss 0.0703, total_loss 0.0801
# Step 000002, dice_loss 0.0099, rbox_loss 0.0370, total_loss 0.0468
# Step 000003, dice_loss 0.0098, rbox_loss 0.0626, total_loss 0.0724
# Step 000004, dice_loss 0.0096, rbox_loss 0.1719, total_loss 0.1814
# Step 000005, dice_loss 0.0096, rbox_loss 0.1028, total_loss 0.1124
# Step 000006, dice_loss 0.0100, rbox_loss 0.0122, total_loss 0.0221
# Step 000007, dice_loss 0.0098, rbox_loss 0.0666, total_loss 0.0764
# Step 000008, dice_loss 0.0098, rbox_loss 0.0586, total_loss 0.0685
# Step 000009, dice_loss 0.0099, rbox_loss 0.0435, total_loss 0.0534
# Step 000010, dice_loss 0.0094, rbox_loss 0.1763, total_loss 0.1857
# Step 000011, dice_loss 0.0097, rbox_loss 0.0510, total_loss 0.0608
# Step 000012, dice_loss 0.0097, rbox_loss 0.0647, total_loss 0.0744
# Step 000013, dice_loss 0.0096, rbox_loss 0.0820, total_loss 0.0916
# Step 000014, dice_loss 0.0096, rbox_loss 0.0789, total_loss 0.0885
# Step 000015, dice_loss 0.0096, rbox_loss 0.0856, total_loss 0.0952
# Step 000016, dice_loss 0.0095, rbox_loss 0.1404, total_loss 0.1498
# Step 000017, dice_loss 0.0100, rbox_loss 0.0082, total_loss 0.0182
# Step 000018, dice_loss 0.0097, rbox_loss 0.0869, total_loss 0.0966
# Step 000019, dice_loss 0.0095, rbox_loss 0.0976, total_loss 0.1071
# Step 000020, dice_loss 0.0093, rbox_loss 0.1171, total_loss 0.1264
# Step 000021, dice_loss 0.0097, rbox_loss 0.0407, total_loss 0.0504
# Step 000022, dice_loss 0.0095, rbox_loss 0.0953, total_loss 0.1048
# Step 000023, dice_loss 0.0097, rbox_loss 0.0701, total_loss 0.0798
# Step 000024, dice_loss 0.0097, rbox_loss 0.0637, total_loss 0.0734
# Step 000025, dice_loss 0.0100, rbox_loss 0.0050, total_loss 0.0150
# Step 000026, dice_loss 0.0099, rbox_loss 0.0111, total_loss 0.0210
# Step 000027, dice_loss 0.0100, rbox_loss 0.0037, total_loss 0.0137
# Step 000028, dice_loss 0.0097, rbox_loss 0.0719, total_loss 0.0816
# Step 000029, dice_loss 0.0099, rbox_loss 0.0434, total_loss 0.0533
# Step 000030, dice_loss 0.0098, rbox_loss 0.0243, total_loss 0.0341
# Step 000031, dice_loss 0.0099, rbox_loss 0.0177, total_loss 0.0276
# Step 000032, dice_loss 0.0098, rbox_loss 0.0376, total_loss 0.0474
# Step 000033, dice_loss 0.0098, rbox_loss 0.0346, total_loss 0.0445
# Step 000034, dice_loss 0.0097, rbox_loss 0.0626, total_loss 0.0723
# Step 000035, dice_loss 0.0098, rbox_loss 0.0485, total_loss 0.0582
# Step 000036, dice_loss 0.0097, rbox_loss 0.0610, total_loss 0.0707
# Step 000037, dice_loss 0.0098, rbox_loss 0.0413, total_loss 0.0511
# Step 000038, dice_loss 0.0099, rbox_loss 0.0287, total_loss 0.0386
# Step 000039, dice_loss 0.0096, rbox_loss 0.0717, total_loss 0.0813
# Step 000040, dice_loss 0.0098, rbox_loss 0.0236, total_loss 0.0335
# Step 000041, dice_loss 0.0100, rbox_loss 0.0025, total_loss 0.0125
# Step 000042, dice_loss 0.0099, rbox_loss 0.0122, total_loss 0.0221
# Step 000043, dice_loss 0.0098, rbox_loss 0.0225, total_loss 0.0323
# Step 000044, dice_loss 0.0099, rbox_loss 0.0187, total_loss 0.0286
# Step 000045, dice_loss 0.0095, rbox_loss 0.0949, total_loss 0.1045
# Step 000046, dice_loss 0.0097, rbox_loss 0.0704, total_loss 0.0801
# Step 000047, dice_loss 0.0098, rbox_loss 0.0283, total_loss 0.0381
# Step 000048, dice_loss 0.0098, rbox_loss 0.0235, total_loss 0.0332
# Step 000049, dice_loss 0.0095, rbox_loss 0.0550, total_loss 0.0645
# Step 000050, dice_loss 0.0099, rbox_loss 0.0191, total_loss 0.0289
# Step 000051, dice_loss 0.0096, rbox_loss 0.0479, total_loss 0.0575
# Step 000052, dice_loss 0.0097, rbox_loss 0.0326, total_loss 0.0423
# Step 000053, dice_loss 0.0095, rbox_loss 0.0697, total_loss 0.0792
# Step 000054, dice_loss 0.0098, rbox_loss 0.0243, total_loss 0.0341
# Step 000055, dice_loss 0.0099, rbox_loss 0.0137, total_loss 0.0236
# Step 000056, dice_loss 0.0098, rbox_loss 0.0257, total_loss 0.0355
# Step 000057, dice_loss 0.0098, rbox_loss 0.0152, total_loss 0.0249
# Step 000058, dice_loss 0.0098, rbox_loss 0.0238, total_loss 0.0336
# Step 000059, dice_loss 0.0095, rbox_loss 0.0690, total_loss 0.0786
# Step 000060, dice_loss 0.0096, rbox_loss 0.0434, total_loss 0.0530
# Step 000061, dice_loss 0.0099, rbox_loss 0.0162, total_loss 0.0261
# invalid poly
# Step 000062, dice_loss 0.0095, rbox_loss 0.0609, total_loss 0.0704
# Step 000063, dice_loss 0.0100, rbox_loss 0.0044, total_loss 0.0144
# Step 000064, dice_loss 0.0097, rbox_loss 0.0352, total_loss 0.0450
# Step 000065, dice_loss 0.0098, rbox_loss 0.0242, total_loss 0.0341
# Step 000066, dice_loss 0.0099, rbox_loss 0.0166, total_loss 0.0265
# Step 000067, dice_loss 0.0095, rbox_loss 0.0562, total_loss 0.0657
# Step 000068, dice_loss 0.0098, rbox_loss 0.0224, total_loss 0.0322
# Step 000069, dice_loss 0.0094, rbox_loss 0.0760, total_loss 0.0854
# Step 000070, dice_loss 0.0099, rbox_loss 0.0079, total_loss 0.0178
# Step 000071, dice_loss 0.0098, rbox_loss 0.0276, total_loss 0.0374
# Step 000072, dice_loss 0.0099, rbox_loss 0.0150, total_loss 0.0249
# Step 000073, dice_loss 0.0100, rbox_loss 0.0017, total_loss 0.0117
# Step 000074, dice_loss 0.0097, rbox_loss 0.0452, total_loss 0.0549
# Step 000075, dice_loss 0.0099, rbox_loss 0.0100, total_loss 0.0199
# Step 000076, dice_loss 0.0098, rbox_loss 0.0334, total_loss 0.0432
# Step 000077, dice_loss 0.0099, rbox_loss 0.0132, total_loss 0.0231
# Step 000078, dice_loss 0.0097, rbox_loss 0.0342, total_loss 0.0440
# Step 000079, dice_loss 0.0093, rbox_loss 0.0668, total_loss 0.0761
# Step 000080, dice_loss 0.0097, rbox_loss 0.0251, total_loss 0.0348
# Step 000081, dice_loss 0.0094, rbox_loss 0.0507, total_loss 0.0601
# Step 000082, dice_loss 0.0096, rbox_loss 0.0383, total_loss 0.0479
# Step 000083, dice_loss 0.0099, rbox_loss 0.0086, total_loss 0.0185
# Step 000084, dice_loss 0.0099, rbox_loss 0.0102, total_loss 0.0201
# Step 000085, dice_loss 0.0095, rbox_loss 0.0442, total_loss 0.0536
# Step 000086, dice_loss 0.0096, rbox_loss 0.0336, total_loss 0.0432
# Step 000087, dice_loss 0.0099, rbox_loss 0.0093, total_loss 0.0191
# Step 000088, dice_loss 0.0097, rbox_loss 0.0207, total_loss 0.0305
# Step 000089, dice_loss 0.0099, rbox_loss 0.0128, total_loss 0.0227
# Step 000090, dice_loss 0.0098, rbox_loss 0.0118, total_loss 0.0216
# Step 000091, dice_loss 0.0098, rbox_loss 0.0212, total_loss 0.0310
# Step 000092, dice_loss 0.0094, rbox_loss 0.0544, total_loss 0.0638
# Step 000093, dice_loss 0.0098, rbox_loss 0.0214, total_loss 0.0311
# Step 000094, dice_loss 0.0093, rbox_loss 0.0469, total_loss 0.0562
# Step 000095, dice_loss 0.0099, rbox_loss 0.0026, total_loss 0.0125
# Step 000096, dice_loss 0.0097, rbox_loss 0.0240, total_loss 0.0336
# Step 000097, dice_loss 0.0098, rbox_loss 0.0112, total_loss 0.0210
# Step 000098, dice_loss 0.0098, rbox_loss 0.0123, total_loss 0.0222
# Step 000099, dice_loss 0.0097, rbox_loss 0.0174, total_loss 0.0271
# Step 000100, dice_loss 0.0097, rbox_loss 0.0290, total_loss 0.0387
# global_step : 100, checkpoint is saved!
# Step 000101, dice_loss 0.0098, rbox_loss 0.0206, total_loss 0.0303
# Step 000102, dice_loss 0.0098, rbox_loss 0.0265, total_loss 0.0363
# Step 000103, dice_loss 0.0099, rbox_loss 0.0053, total_loss 0.0152
# Step 000104, dice_loss 0.0096, rbox_loss 0.0272, total_loss 0.0368
# Step 000105, dice_loss 0.0095, rbox_loss 0.0385, total_loss 0.0481
# Step 000106, dice_loss 0.0097, rbox_loss 0.0312, total_loss 0.0409
# Step 000107, dice_loss 0.0099, rbox_loss 0.0183, total_loss 0.0282
# Step 000108, dice_loss 0.0100, rbox_loss 0.0025, total_loss 0.0125
# Step 000109, dice_loss 0.0097, rbox_loss 0.0233, total_loss 0.0330
# Step 000110, dice_loss 0.0099, rbox_loss 0.0075, total_loss 0.0175
# Step 000111, dice_loss 0.0092, rbox_loss 0.0644, total_loss 0.0736
# Step 000112, dice_loss 0.0099, rbox_loss 0.0088, total_loss 0.0187
# Step 000113, dice_loss 0.0093, rbox_loss 0.0498, total_loss 0.0590
# Step 000114, dice_loss 0.0097, rbox_loss 0.0175, total_loss 0.0272
# Step 000115, dice_loss 0.0100, rbox_loss 0.0007, total_loss 0.0107
# Step 000116, dice_loss 0.0095, rbox_loss 0.0302, total_loss 0.0397
# Step 000117, dice_loss 0.0097, rbox_loss 0.0212, total_loss 0.0308
# Step 000118, dice_loss 0.0099, rbox_loss 0.0093, total_loss 0.0191
# Step 000119, dice_loss 0.0095, rbox_loss 0.0319, total_loss 0.0414
# Step 000120, dice_loss 0.0095, rbox_loss 0.0314, total_loss 0.0409
# Step 000121, dice_loss 0.0099, rbox_loss 0.0078, total_loss 0.0176
# Step 000122, dice_loss 0.0095, rbox_loss 0.0345, total_loss 0.0440
# Step 000123, dice_loss 0.0095, rbox_loss 0.0261, total_loss 0.0356
# Step 000124, dice_loss 0.0096, rbox_loss 0.0250, total_loss 0.0347
# Step 000125, dice_loss 0.0095, rbox_loss 0.0308, total_loss 0.0404
# Step 000126, dice_loss 0.0096, rbox_loss 0.0254, total_loss 0.0349
# Step 000127, dice_loss 0.0095, rbox_loss 0.0317, total_loss 0.0412
# Step 000128, dice_loss 0.0097, rbox_loss 0.0160, total_loss 0.0257
# Step 000129, dice_loss 0.0099, rbox_loss 0.0091, total_loss 0.0189
# Step 000130, dice_loss 0.0099, rbox_loss 0.0094, total_loss 0.0193
# Step 000131, dice_loss 0.0096, rbox_loss 0.0312, total_loss 0.0407
# Step 000132, dice_loss 0.0097, rbox_loss 0.0213, total_loss 0.0309
# Step 000133, dice_loss 0.0096, rbox_loss 0.0235, total_loss 0.0330
# Step 000134, dice_loss 0.0096, rbox_loss 0.0249, total_loss 0.0345
# Step 000135, dice_loss 0.0097, rbox_loss 0.0158, total_loss 0.0255
# Step 000136, dice_loss 0.0099, rbox_loss 0.0088, total_loss 0.0187
# Step 000137, dice_loss 0.0096, rbox_loss 0.0256, total_loss 0.0351
# Step 000138, dice_loss 0.0094, rbox_loss 0.0407, total_loss 0.0500
# Step 000139, dice_loss 0.0097, rbox_loss 0.0122, total_loss 0.0219
# Step 000140, dice_loss 0.0097, rbox_loss 0.0211, total_loss 0.0308
# Step 000141, dice_loss 0.0097, rbox_loss 0.0184, total_loss 0.0281
# Step 000142, dice_loss 0.0097, rbox_loss 0.0208, total_loss 0.0305
# Step 000143, dice_loss 0.0098, rbox_loss 0.0109, total_loss 0.0207
# Step 000144, dice_loss 0.0098, rbox_loss 0.0151, total_loss 0.0249
# Step 000145, dice_loss 0.0099, rbox_loss 0.0034, total_loss 0.0134
# Step 000146, dice_loss 0.0094, rbox_loss 0.0296, total_loss 0.0390
# Step 000147, dice_loss 0.0098, rbox_loss 0.0121, total_loss 0.0219
# Step 000148, dice_loss 0.0099, rbox_loss 0.0083, total_loss 0.0181
# Step 000149, dice_loss 0.0100, rbox_loss 0.0035, total_loss 0.0134
# Step 000150, dice_loss 0.0098, rbox_loss 0.0081, total_loss 0.0179
# Step 000151, dice_loss 0.0094, rbox_loss 0.0312, total_loss 0.0407
# Step 000152, dice_loss 0.0095, rbox_loss 0.0316, total_loss 0.0411
# Step 000153, dice_loss 0.0099, rbox_loss 0.0058, total_loss 0.0157
# Step 000154, dice_loss 0.0098, rbox_loss 0.0151, total_loss 0.0249
# Step 000155, dice_loss 0.0096, rbox_loss 0.0352, total_loss 0.0448
# Step 000156, dice_loss 0.0094, rbox_loss 0.0330, total_loss 0.0424
# Step 000157, dice_loss 0.0097, rbox_loss 0.0190, total_loss 0.0287
# Step 000158, dice_loss 0.0098, rbox_loss 0.0123, total_loss 0.0221
# Step 000159, dice_loss 0.0098, rbox_loss 0.0149, total_loss 0.0247
# Step 000160, dice_loss 0.0099, rbox_loss 0.0031, total_loss 0.0130
# Step 000161, dice_loss 0.0098, rbox_loss 0.0185, total_loss 0.0282
# Step 000162, dice_loss 0.0091, rbox_loss 0.0560, total_loss 0.0651
# Step 000163, dice_loss 0.0096, rbox_loss 0.0321, total_loss 0.0417
# Step 000164, dice_loss 0.0097, rbox_loss 0.0159, total_loss 0.0256
# Step 000165, dice_loss 0.0099, rbox_loss 0.0083, total_loss 0.0181
# Step 000166, dice_loss 0.0098, rbox_loss 0.0115, total_loss 0.0214
# Step 000167, dice_loss 0.0099, rbox_loss 0.0104, total_loss 0.0203
# Step 000168, dice_loss 0.0099, rbox_loss 0.0054, total_loss 0.0153
# Step 000169, dice_loss 0.0094, rbox_loss 0.0390, total_loss 0.0485
# Step 000170, dice_loss 0.0097, rbox_loss 0.0246, total_loss 0.0343
# Step 000171, dice_loss 0.0097, rbox_loss 0.0240, total_loss 0.0336
# Step 000172, dice_loss 0.0095, rbox_loss 0.0240, total_loss 0.0336
# Step 000173, dice_loss 0.0099, rbox_loss 0.0161, total_loss 0.0259
# Step 000174, dice_loss 0.0095, rbox_loss 0.0263, total_loss 0.0358
# Step 000175, dice_loss 0.0095, rbox_loss 0.0320, total_loss 0.0415
# Step 000176, dice_loss 0.0092, rbox_loss 0.0464, total_loss 0.0556
# Step 000177, dice_loss 0.0099, rbox_loss 0.0048, total_loss 0.0147
# Step 000178, dice_loss 0.0098, rbox_loss 0.0126, total_loss 0.0223
# Step 000179, dice_loss 0.0094, rbox_loss 0.0425, total_loss 0.0519
# Step 000180, dice_loss 0.0095, rbox_loss 0.0285, total_loss 0.0380
# Step 000181, dice_loss 0.0099, rbox_loss 0.0045, total_loss 0.0144
# Step 000182, dice_loss 0.0098, rbox_loss 0.0099, total_loss 0.0197
# Step 000183, dice_loss 0.0096, rbox_loss 0.0307, total_loss 0.0403
# Step 000184, dice_loss 0.0098, rbox_loss 0.0188, total_loss 0.0287
# Step 000185, dice_loss 0.0096, rbox_loss 0.0227, total_loss 0.0322
# Step 000186, dice_loss 0.0096, rbox_loss 0.0182, total_loss 0.0278
# Step 000187, dice_loss 0.0097, rbox_loss 0.0171, total_loss 0.0268
# Step 000188, dice_loss 0.0097, rbox_loss 0.0187, total_loss 0.0284
# Step 000189, dice_loss 0.0097, rbox_loss 0.0193, total_loss 0.0290
# Step 000190, dice_loss 0.0092, rbox_loss 0.0374, total_loss 0.0466
# Step 000191, dice_loss 0.0098, rbox_loss 0.0135, total_loss 0.0233
# Step 000192, dice_loss 0.0093, rbox_loss 0.0351, total_loss 0.0444
# Step 000193, dice_loss 0.0097, rbox_loss 0.0169, total_loss 0.0266
# Step 000194, dice_loss 0.0098, rbox_loss 0.0078, total_loss 0.0176
# Step 000195, dice_loss 0.0094, rbox_loss 0.0288, total_loss 0.0382
# Step 000196, dice_loss 0.0092, rbox_loss 0.0430, total_loss 0.0521
# Step 000197, dice_loss 0.0098, rbox_loss 0.0138, total_loss 0.0236
# Step 000198, dice_loss 0.0098, rbox_loss 0.0126, total_loss 0.0224
# Step 000199, dice_loss 0.0094, rbox_loss 0.0316, total_loss 0.0410
# Step 000200, dice_loss 0.0096, rbox_loss 0.0198, total_loss 0.0293
# global_step : 200, checkpoint is saved!
# Step 000201, dice_loss 0.0099, rbox_loss 0.0058, total_loss 0.0156
# Step 000202, dice_loss 0.0096, rbox_loss 0.0202, total_loss 0.0298
# Step 000203, dice_loss 0.0098, rbox_loss 0.0111, total_loss 0.0209
# Step 000204, dice_loss 0.0093, rbox_loss 0.0461, total_loss 0.0554
# Step 000205, dice_loss 0.0096, rbox_loss 0.0195, total_loss 0.0291
# Step 000206, dice_loss 0.0099, rbox_loss 0.0076, total_loss 0.0175
# Step 000207, dice_loss 0.0095, rbox_loss 0.0264, total_loss 0.0360
# Step 000208, dice_loss 0.0099, rbox_loss 0.0100, total_loss 0.0198
# Step 000209, dice_loss 0.0094, rbox_loss 0.0297, total_loss 0.0391
# Step 000210, dice_loss 0.0096, rbox_loss 0.0249, total_loss 0.0345
# Step 000211, dice_loss 0.0096, rbox_loss 0.0186, total_loss 0.0282
# Step 000212, dice_loss 0.0099, rbox_loss 0.0086, total_loss 0.0184
# Step 000213, dice_loss 0.0095, rbox_loss 0.0264, total_loss 0.0358
# Step 000214, dice_loss 0.0093, rbox_loss 0.0386, total_loss 0.0479
# Step 000215, dice_loss 0.0096, rbox_loss 0.0189, total_loss 0.0286
# Step 000216, dice_loss 0.0095, rbox_loss 0.0279, total_loss 0.0374
# Step 000217, dice_loss 0.0099, rbox_loss 0.0066, total_loss 0.0165
# Step 000218, dice_loss 0.0094, rbox_loss 0.0268, total_loss 0.0363
# Step 000219, dice_loss 0.0094, rbox_loss 0.0296, total_loss 0.0390
# Step 000220, dice_loss 0.0099, rbox_loss 0.0039, total_loss 0.0138
# Step 000221, dice_loss 0.0095, rbox_loss 0.0202, total_loss 0.0297
# Step 000222, dice_loss 0.0098, rbox_loss 0.0075, total_loss 0.0174
# Step 000223, dice_loss 0.0097, rbox_loss 0.0115, total_loss 0.0212
# Step 000224, dice_loss 0.0097, rbox_loss 0.0188, total_loss 0.0284
# Step 000225, dice_loss 0.0094, rbox_loss 0.0212, total_loss 0.0306
# Step 000226, dice_loss 0.0100, rbox_loss 0.0028, total_loss 0.0128
# Step 000227, dice_loss 0.0097, rbox_loss 0.0170, total_loss 0.0267
# Step 000228, dice_loss 0.0093, rbox_loss 0.0298, total_loss 0.0391
# Step 000229, dice_loss 0.0095, rbox_loss 0.0238, total_loss 0.0334
# Step 000230, dice_loss 0.0097, rbox_loss 0.0108, total_loss 0.0206
# Step 000231, dice_loss 0.0095, rbox_loss 0.0191, total_loss 0.0286
# Step 000232, dice_loss 0.0096, rbox_loss 0.0142, total_loss 0.0238
# Step 000233, dice_loss 0.0093, rbox_loss 0.0282, total_loss 0.0376
# Step 000234, dice_loss 0.0098, rbox_loss 0.0059, total_loss 0.0157
# Step 000235, dice_loss 0.0095, rbox_loss 0.0238, total_loss 0.0334
# Step 000236, dice_loss 0.0092, rbox_loss 0.0364, total_loss 0.0456
# Step 000237, dice_loss 0.0100, rbox_loss 0.0026, total_loss 0.0125
# Step 000238, dice_loss 0.0093, rbox_loss 0.0311, total_loss 0.0404
# Step 000239, dice_loss 0.0097, rbox_loss 0.0139, total_loss 0.0236
# Step 000240, dice_loss 0.0099, rbox_loss 0.0068, total_loss 0.0167
# Step 000241, dice_loss 0.0097, rbox_loss 0.0150, total_loss 0.0248
# Step 000242, dice_loss 0.0095, rbox_loss 0.0314, total_loss 0.0410
# Step 000243, dice_loss 0.0093, rbox_loss 0.0411, total_loss 0.0504
# Step 000244, dice_loss 0.0099, rbox_loss 0.0061, total_loss 0.0160
# Step 000245, dice_loss 0.0092, rbox_loss 0.0361, total_loss 0.0453
# Step 000246, dice_loss 0.0098, rbox_loss 0.0058, total_loss 0.0156
# Step 000247, dice_loss 0.0093, rbox_loss 0.0269, total_loss 0.0363
# Step 000248, dice_loss 0.0098, rbox_loss 0.0089, total_loss 0.0187
# Step 000249, dice_loss 0.0095, rbox_loss 0.0185, total_loss 0.0280
# Step 000250, dice_loss 0.0097, rbox_loss 0.0150, total_loss 0.0246
# Step 000251, dice_loss 0.0095, rbox_loss 0.0208, total_loss 0.0303
# Step 000252, dice_loss 0.0094, rbox_loss 0.0244, total_loss 0.0338
# Step 000253, dice_loss 0.0088, rbox_loss 0.0502, total_loss 0.0590
# Step 000254, dice_loss 0.0094, rbox_loss 0.0284, total_loss 0.0377
# Step 000255, dice_loss 0.0100, rbox_loss 0.0018, total_loss 0.0118
# Step 000256, dice_loss 0.0098, rbox_loss 0.0143, total_loss 0.0242
# Step 000257, dice_loss 0.0094, rbox_loss 0.0307, total_loss 0.0401
# Step 000258, dice_loss 0.0097, rbox_loss 0.0172, total_loss 0.0269
# Step 000259, dice_loss 0.0100, rbox_loss 0.0030, total_loss 0.0130
# Step 000260, dice_loss 0.0093, rbox_loss 0.0342, total_loss 0.0435
# Step 000261, dice_loss 0.0099, rbox_loss 0.0083, total_loss 0.0182
# Step 000262, dice_loss 0.0096, rbox_loss 0.0268, total_loss 0.0364
# Step 000263, dice_loss 0.0094, rbox_loss 0.0480, total_loss 0.0574
# Step 000264, dice_loss 0.0099, rbox_loss 0.0111, total_loss 0.0210
# Step 000265, dice_loss 0.0096, rbox_loss 0.0180, total_loss 0.0276
# Step 000266, dice_loss 0.0091, rbox_loss 0.0373, total_loss 0.0464
# Step 000267, dice_loss 0.0091, rbox_loss 0.0407, total_loss 0.0498
# Step 000268, dice_loss 0.0092, rbox_loss 0.0407, total_loss 0.0498
# C:\Users\farra\AppData\Local\Temp\ipykernel_26924\1275249081.py:246: RuntimeWarning: invalid value encountered in scalar divide
#   return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)
# Step 000269, dice_loss 0.0098, rbox_loss 0.0111, total_loss 0.0208
# Step 000270, dice_loss 0.0092, rbox_loss 0.0386, total_loss 0.0479
# Step 000271, dice_loss 0.0096, rbox_loss 0.0168, total_loss 0.0265
# Step 000272, dice_loss 0.0099, rbox_loss 0.0085, total_loss 0.0184
# Step 000273, dice_loss 0.0096, rbox_loss 0.0138, total_loss 0.0234
# Step 000274, dice_loss 0.0094, rbox_loss 0.0214, total_loss 0.0308
# Step 000275, dice_loss 0.0098, rbox_loss 0.0097, total_loss 0.0195
# Step 000276, dice_loss 0.0097, rbox_loss 0.0099, total_loss 0.0197
# Step 000277, dice_loss 0.0094, rbox_loss 0.0227, total_loss 0.0321
# Step 000278, dice_loss 0.0097, rbox_loss 0.0151, total_loss 0.0248
# Step 000279, dice_loss 0.0098, rbox_loss 0.0068, total_loss 0.0167
# Step 000280, dice_loss 0.0099, rbox_loss 0.0027, total_loss 0.0126
# Step 000281, dice_loss 0.0096, rbox_loss 0.0192, total_loss 0.0288
# Step 000282, dice_loss 0.0099, rbox_loss 0.0043, total_loss 0.0142
# Step 000283, dice_loss 0.0099, rbox_loss 0.0024, total_loss 0.0124
# Step 000284, dice_loss 0.0098, rbox_loss 0.0081, total_loss 0.0178
# Step 000285, dice_loss 0.0097, rbox_loss 0.0122, total_loss 0.0220
# Step 000286, dice_loss 0.0094, rbox_loss 0.0220, total_loss 0.0314
# Step 000287, dice_loss 0.0096, rbox_loss 0.0113, total_loss 0.0210
# Step 000288, dice_loss 0.0089, rbox_loss 0.0432, total_loss 0.0521
# Step 000289, dice_loss 0.0097, rbox_loss 0.0131, total_loss 0.0228
# Step 000290, dice_loss 0.0097, rbox_loss 0.0117, total_loss 0.0214
# Step 000291, dice_loss 0.0090, rbox_loss 0.0298, total_loss 0.0388
# Step 000292, dice_loss 0.0097, rbox_loss 0.0090, total_loss 0.0187
# Step 000293, dice_loss 0.0094, rbox_loss 0.0217, total_loss 0.0311
# Step 000294, dice_loss 0.0094, rbox_loss 0.0273, total_loss 0.0366
# Step 000295, dice_loss 0.0097, rbox_loss 0.0072, total_loss 0.0170
# Step 000296, dice_loss 0.0095, rbox_loss 0.0170, total_loss 0.0265
# Step 000297, dice_loss 0.0097, rbox_loss 0.0097, total_loss 0.0194
# Step 000298, dice_loss 0.0093, rbox_loss 0.0239, total_loss 0.0332
# Step 000299, dice_loss 0.0093, rbox_loss 0.0206, total_loss 0.0299
# Step 000300, dice_loss 0.0094, rbox_loss 0.0153, total_loss 0.0247
# global_step : 300, checkpoint is saved!
# Step 000301, dice_loss 0.0097, rbox_loss 0.0102, total_loss 0.0199
# Step 000302, dice_loss 0.0097, rbox_loss 0.0095, total_loss 0.0192
# Step 000303, dice_loss 0.0092, rbox_loss 0.0251, total_loss 0.0343
# Step 000304, dice_loss 0.0093, rbox_loss 0.0211, total_loss 0.0304
# Step 000305, dice_loss 0.0089, rbox_loss 0.0382, total_loss 0.0471
# Step 000306, dice_loss 0.0099, rbox_loss 0.0016, total_loss 0.0115
# Step 000307, dice_loss 0.0099, rbox_loss 0.0061, total_loss 0.0160
# Step 000308, dice_loss 0.0095, rbox_loss 0.0229, total_loss 0.0324
# Step 000309, dice_loss 0.0096, rbox_loss 0.0207, total_loss 0.0303
# Step 000310, dice_loss 0.0089, rbox_loss 0.0440, total_loss 0.0529
# Step 000311, dice_loss 0.0095, rbox_loss 0.0131, total_loss 0.0226
# Step 000312, dice_loss 0.0095, rbox_loss 0.0107, total_loss 0.0202
# Step 000313, dice_loss 0.0097, rbox_loss 0.0087, total_loss 0.0185
# Step 000314, dice_loss 0.0088, rbox_loss 0.0415, total_loss 0.0503
# Step 000315, dice_loss 0.0099, rbox_loss 0.0054, total_loss 0.0152
# Step 000316, dice_loss 0.0096, rbox_loss 0.0091, total_loss 0.0187
# Step 000317, dice_loss 0.0096, rbox_loss 0.0123, total_loss 0.0219
# Step 000318, dice_loss 0.0097, rbox_loss 0.0091, total_loss 0.0188
# Step 000319, dice_loss 0.0091, rbox_loss 0.0296, total_loss 0.0387
# Step 000320, dice_loss 0.0099, rbox_loss 0.0046, total_loss 0.0145
# Step 000321, dice_loss 0.0093, rbox_loss 0.0272, total_loss 0.0365
# Step 000322, dice_loss 0.0095, rbox_loss 0.0172, total_loss 0.0267
# Step 000323, dice_loss 0.0100, rbox_loss 0.0030, total_loss 0.0130
# Step 000324, dice_loss 0.0084, rbox_loss 0.0651, total_loss 0.0734
# Step 000325, dice_loss 0.0097, rbox_loss 0.0091, total_loss 0.0188
# Step 000326, dice_loss 0.0098, rbox_loss 0.0118, total_loss 0.0217
# Step 000327, dice_loss 0.0094, rbox_loss 0.0210, total_loss 0.0303
# Step 000328, dice_loss 0.0094, rbox_loss 0.0216, total_loss 0.0309
# Step 000329, dice_loss 0.0098, rbox_loss 0.0070, total_loss 0.0168
# Step 000330, dice_loss 0.0095, rbox_loss 0.0184, total_loss 0.0279
# Step 000331, dice_loss 0.0099, rbox_loss 0.0023, total_loss 0.0122
# Step 000332, dice_loss 0.0099, rbox_loss 0.0044, total_loss 0.0143
# Step 000333, dice_loss 0.0093, rbox_loss 0.0255, total_loss 0.0348
# Step 000334, dice_loss 0.0089, rbox_loss 0.0429, total_loss 0.0519
# Step 000335, dice_loss 0.0093, rbox_loss 0.0259, total_loss 0.0352
# Step 000336, dice_loss 0.0097, rbox_loss 0.0130, total_loss 0.0226
# Step 000337, dice_loss 0.0096, rbox_loss 0.0104, total_loss 0.0200
# Step 000338, dice_loss 0.0096, rbox_loss 0.0139, total_loss 0.0235
# Step 000339, dice_loss 0.0097, rbox_loss 0.0137, total_loss 0.0234
# Step 000340, dice_loss 0.0097, rbox_loss 0.0078, total_loss 0.0175
# Step 000341, dice_loss 0.0095, rbox_loss 0.0194, total_loss 0.0289
# Step 000342, dice_loss 0.0099, rbox_loss 0.0026, total_loss 0.0125
# Step 000343, dice_loss 0.0088, rbox_loss 0.0376, total_loss 0.0464
# Step 000344, dice_loss 0.0099, rbox_loss 0.0042, total_loss 0.0141
# Step 000345, dice_loss 0.0091, rbox_loss 0.0260, total_loss 0.0351
# Step 000346, dice_loss 0.0093, rbox_loss 0.0154, total_loss 0.0248
# Step 000347, dice_loss 0.0095, rbox_loss 0.0101, total_loss 0.0196
# Step 000348, dice_loss 0.0092, rbox_loss 0.0186, total_loss 0.0278
# Step 000349, dice_loss 0.0091, rbox_loss 0.0207, total_loss 0.0298
# Step 000350, dice_loss 0.0092, rbox_loss 0.0183, total_loss 0.0275
# Step 000351, dice_loss 0.0090, rbox_loss 0.0230, total_loss 0.0320
# Step 000352, dice_loss 0.0093, rbox_loss 0.0251, total_loss 0.0344
# Step 000353, dice_loss 0.0093, rbox_loss 0.0175, total_loss 0.0268
# Step 000354, dice_loss 0.0093, rbox_loss 0.0161, total_loss 0.0254
# Step 000355, dice_loss 0.0095, rbox_loss 0.0135, total_loss 0.0230
# Step 000356, dice_loss 0.0098, rbox_loss 0.0047, total_loss 0.0145
# Step 000357, dice_loss 0.0094, rbox_loss 0.0143, total_loss 0.0237
# Step 000358, dice_loss 0.0100, rbox_loss 0.0008, total_loss 0.0107
# Step 000359, dice_loss 0.0095, rbox_loss 0.0128, total_loss 0.0223
# Step 000360, dice_loss 0.0093, rbox_loss 0.0171, total_loss 0.0264
# Step 000361, dice_loss 0.0087, rbox_loss 0.0326, total_loss 0.0413
# Step 000362, dice_loss 0.0092, rbox_loss 0.0317, total_loss 0.0409
# Step 000363, dice_loss 0.0093, rbox_loss 0.0190, total_loss 0.0283
# Step 000364, dice_loss 0.0093, rbox_loss 0.0195, total_loss 0.0288
# Step 000365, dice_loss 0.0086, rbox_loss 0.0338, total_loss 0.0424
# Step 000366, dice_loss 0.0094, rbox_loss 0.0146, total_loss 0.0240
# Step 000367, dice_loss 0.0089, rbox_loss 0.0315, total_loss 0.0403
# Step 000368, dice_loss 0.0088, rbox_loss 0.0315, total_loss 0.0403
# Step 000369, dice_loss 0.0094, rbox_loss 0.0140, total_loss 0.0234
# Step 000370, dice_loss 0.0093, rbox_loss 0.0108, total_loss 0.0202
# Step 000371, dice_loss 0.0099, rbox_loss 0.0033, total_loss 0.0132
# Step 000372, dice_loss 0.0090, rbox_loss 0.0191, total_loss 0.0282
# Step 000373, dice_loss 0.0095, rbox_loss 0.0104, total_loss 0.0199
# Step 000374, dice_loss 0.0098, rbox_loss 0.0041, total_loss 0.0139
# Step 000375, dice_loss 0.0096, rbox_loss 0.0083, total_loss 0.0180
# Step 000376, dice_loss 0.0093, rbox_loss 0.0208, total_loss 0.0301
# Step 000377, dice_loss 0.0095, rbox_loss 0.0092, total_loss 0.0187
# Step 000378, dice_loss 0.0090, rbox_loss 0.0267, total_loss 0.0357
# Step 000379, dice_loss 0.0086, rbox_loss 0.0297, total_loss 0.0384
# Step 000380, dice_loss 0.0094, rbox_loss 0.0113, total_loss 0.0207
# Step 000381, dice_loss 0.0091, rbox_loss 0.0146, total_loss 0.0237
# Step 000382, dice_loss 0.0095, rbox_loss 0.0075, total_loss 0.0170
# Step 000383, dice_loss 0.0092, rbox_loss 0.0161, total_loss 0.0253
# Step 000384, dice_loss 0.0099, rbox_loss 0.0017, total_loss 0.0116
# Step 000385, dice_loss 0.0085, rbox_loss 0.0291, total_loss 0.0375
# Step 000386, dice_loss 0.0086, rbox_loss 0.0262, total_loss 0.0347
# Step 000387, dice_loss 0.0084, rbox_loss 0.0294, total_loss 0.0378
# Step 000388, dice_loss 0.0093, rbox_loss 0.0151, total_loss 0.0243
# invalid poly
# Step 000389, dice_loss 0.0089, rbox_loss 0.0209, total_loss 0.0297
# Step 000390, dice_loss 0.0088, rbox_loss 0.0197, total_loss 0.0284
# Step 000391, dice_loss 0.0086, rbox_loss 0.0169, total_loss 0.0255
# Step 000392, dice_loss 0.0079, rbox_loss 0.0370, total_loss 0.0449
# Step 000393, dice_loss 0.0080, rbox_loss 0.0226, total_loss 0.0306
# Step 000394, dice_loss 0.0078, rbox_loss 0.0238, total_loss 0.0316
# Step 000395, dice_loss 0.0092, rbox_loss 0.0052, total_loss 0.0144
# Step 000396, dice_loss 0.0081, rbox_loss 0.0218, total_loss 0.0300
# Step 000397, dice_loss 0.0085, rbox_loss 0.0259, total_loss 0.0344
# Step 000398, dice_loss 0.0082, rbox_loss 0.0255, total_loss 0.0338
# Step 000399, dice_loss 0.0074, rbox_loss 0.0443, total_loss 0.0517
# Step 000400, dice_loss 0.0092, rbox_loss 0.0138, total_loss 0.0229
# global_step : 400, checkpoint is saved!
# Step 000401, dice_loss 0.0095, rbox_loss 0.0128, total_loss 0.0224
# Step 000402, dice_loss 0.0085, rbox_loss 0.0354, total_loss 0.0439
# Step 000403, dice_loss 0.0088, rbox_loss 0.0207, total_loss 0.0295
# Step 000404, dice_loss 0.0093, rbox_loss 0.0111, total_loss 0.0205
# Step 000405, dice_loss 0.0089, rbox_loss 0.0246, total_loss 0.0335
# Step 000406, dice_loss 0.0086, rbox_loss 0.0206, total_loss 0.0292
# Step 000407, dice_loss 0.0090, rbox_loss 0.0226, total_loss 0.0316
# Step 000408, dice_loss 0.0085, rbox_loss 0.0316, total_loss 0.0401
# Step 000409, dice_loss 0.0074, rbox_loss 0.0418, total_loss 0.0492
# Step 000410, dice_loss 0.0098, rbox_loss 0.0033, total_loss 0.0131
# Step 000411, dice_loss 0.0083, rbox_loss 0.0200, total_loss 0.0283
# Step 000412, dice_loss 0.0065, rbox_loss 0.0411, total_loss 0.0476
# Step 000413, dice_loss 0.0074, rbox_loss 0.0256, total_loss 0.0330
# Step 000414, dice_loss 0.0091, rbox_loss 0.0088, total_loss 0.0179
# Step 000415, dice_loss 0.0099, rbox_loss 0.0014, total_loss 0.0113
# Step 000416, dice_loss 0.0087, rbox_loss 0.0224, total_loss 0.0311
# Step 000417, dice_loss 0.0076, rbox_loss 0.0250, total_loss 0.0326
# Step 000418, dice_loss 0.0095, rbox_loss 0.0051, total_loss 0.0147
# Step 000419, dice_loss 0.0079, rbox_loss 0.0155, total_loss 0.0233
# Step 000420, dice_loss 0.0067, rbox_loss 0.0286, total_loss 0.0354
# Step 000421, dice_loss 0.0098, rbox_loss 0.0020, total_loss 0.0117
# Step 000422, dice_loss 0.0082, rbox_loss 0.0169, total_loss 0.0252
# Step 000423, dice_loss 0.0077, rbox_loss 0.0247, total_loss 0.0324
# Step 000424, dice_loss 0.0087, rbox_loss 0.0078, total_loss 0.0166
# Step 000425, dice_loss 0.0089, rbox_loss 0.0126, total_loss 0.0215
# Step 000426, dice_loss 0.0082, rbox_loss 0.0089, total_loss 0.0171
# Step 000427, dice_loss 0.0082, rbox_loss 0.0241, total_loss 0.0323
# Step 000428, dice_loss 0.0095, rbox_loss 0.0084, total_loss 0.0179
# Step 000429, dice_loss 0.0095, rbox_loss 0.0025, total_loss 0.0120
# Step 000430, dice_loss 0.0070, rbox_loss 0.0317, total_loss 0.0387
# Step 000431, dice_loss 0.0066, rbox_loss 0.0473, total_loss 0.0539
# Step 000432, dice_loss 0.0088, rbox_loss 0.0052, total_loss 0.0141
# Step 000433, dice_loss 0.0086, rbox_loss 0.0115, total_loss 0.0201
# Step 000434, dice_loss 0.0086, rbox_loss 0.0165, total_loss 0.0251
# Step 000435, dice_loss 0.0079, rbox_loss 0.0233, total_loss 0.0312
# Step 000436, dice_loss 0.0097, rbox_loss 0.0109, total_loss 0.0206
# Step 000437, dice_loss 0.0088, rbox_loss 0.0086, total_loss 0.0174
# Step 000438, dice_loss 0.0080, rbox_loss 0.0210, total_loss 0.0290
# Step 000439, dice_loss 0.0098, rbox_loss 0.0025, total_loss 0.0122
# Step 000440, dice_loss 0.0098, rbox_loss 0.0043, total_loss 0.0141
# Step 000441, dice_loss 0.0079, rbox_loss 0.0202, total_loss 0.0282
# Step 000442, dice_loss 0.0086, rbox_loss 0.0130, total_loss 0.0216
# Step 000443, dice_loss 0.0082, rbox_loss 0.0254, total_loss 0.0335
# Step 000444, dice_loss 0.0082, rbox_loss 0.0123, total_loss 0.0205
# Step 000445, dice_loss 0.0077, rbox_loss 0.0167, total_loss 0.0243
# Step 000446, dice_loss 0.0095, rbox_loss 0.0033, total_loss 0.0128
# Step 000447, dice_loss 0.0096, rbox_loss 0.0051, total_loss 0.0146
# Step 000448, dice_loss 0.0076, rbox_loss 0.0190, total_loss 0.0266
# Step 000449, dice_loss 0.0085, rbox_loss 0.0130, total_loss 0.0215
# Step 000450, dice_loss 0.0068, rbox_loss 0.0255, total_loss 0.0324
# Step 000451, dice_loss 0.0087, rbox_loss 0.0090, total_loss 0.0177
# Step 000452, dice_loss 0.0068, rbox_loss 0.0089, total_loss 0.0157
# Step 000453, dice_loss 0.0070, rbox_loss 0.0213, total_loss 0.0283
# Step 000454, dice_loss 0.0069, rbox_loss 0.0117, total_loss 0.0186
# Step 000455, dice_loss 0.0062, rbox_loss 0.0333, total_loss 0.0394
# Step 000456, dice_loss 0.0075, rbox_loss 0.0125, total_loss 0.0200
# Step 000457, dice_loss 0.0097, rbox_loss 0.0027, total_loss 0.0124
# Step 000458, dice_loss 0.0088, rbox_loss 0.0406, total_loss 0.0494
# Step 000459, dice_loss 0.0079, rbox_loss 0.0327, total_loss 0.0406
# Step 000460, dice_loss 0.0093, rbox_loss 0.0150, total_loss 0.0243
# Step 000461, dice_loss 0.0096, rbox_loss 0.0206, total_loss 0.0302
# Step 000462, dice_loss 0.0088, rbox_loss 0.0488, total_loss 0.0576
# Step 000463, dice_loss 0.0099, rbox_loss 0.0051, total_loss 0.0150
# Step 000464, dice_loss 0.0098, rbox_loss 0.0082, total_loss 0.0180
# Step 000465, dice_loss 0.0094, rbox_loss 0.0244, total_loss 0.0338
# Step 000466, dice_loss 0.0097, rbox_loss 0.0138, total_loss 0.0234
# Step 000467, dice_loss 0.0097, rbox_loss 0.0146, total_loss 0.0243
# Step 000468, dice_loss 0.0094, rbox_loss 0.0250, total_loss 0.0344
# Step 000469, dice_loss 0.0097, rbox_loss 0.0130, total_loss 0.0227
# Step 000470, dice_loss 0.0098, rbox_loss 0.0086, total_loss 0.0183
# Step 000471, dice_loss 0.0099, rbox_loss 0.0057, total_loss 0.0156
# Step 000472, dice_loss 0.0091, rbox_loss 0.0330, total_loss 0.0422
# Step 000473, dice_loss 0.0098, rbox_loss 0.0052, total_loss 0.0150
# Step 000474, dice_loss 0.0096, rbox_loss 0.0111, total_loss 0.0208
# Step 000475, dice_loss 0.0096, rbox_loss 0.0162, total_loss 0.0257
# Step 000476, dice_loss 0.0097, rbox_loss 0.0178, total_loss 0.0275
# Step 000477, dice_loss 0.0097, rbox_loss 0.0104, total_loss 0.0202
# Step 000478, dice_loss 0.0094, rbox_loss 0.0257, total_loss 0.0351
# Step 000479, dice_loss 0.0099, rbox_loss 0.0031, total_loss 0.0130
# Step 000480, dice_loss 0.0095, rbox_loss 0.0147, total_loss 0.0242
# Step 000481, dice_loss 0.0095, rbox_loss 0.0150, total_loss 0.0245
# Step 000482, dice_loss 0.0095, rbox_loss 0.0182, total_loss 0.0277
# Step 000483, dice_loss 0.0095, rbox_loss 0.0206, total_loss 0.0301
# Step 000484, dice_loss 0.0096, rbox_loss 0.0116, total_loss 0.0213
# Step 000485, dice_loss 0.0097, rbox_loss 0.0115, total_loss 0.0212
# Step 000486, dice_loss 0.0099, rbox_loss 0.0039, total_loss 0.0138
# Step 000487, dice_loss 0.0095, rbox_loss 0.0208, total_loss 0.0302
# Step 000488, dice_loss 0.0099, rbox_loss 0.0054, total_loss 0.0153
# Step 000489, dice_loss 0.0094, rbox_loss 0.0200, total_loss 0.0293
# Step 000490, dice_loss 0.0096, rbox_loss 0.0123, total_loss 0.0219
# Step 000491, dice_loss 0.0094, rbox_loss 0.0198, total_loss 0.0291
# Step 000492, dice_loss 0.0097, rbox_loss 0.0161, total_loss 0.0258
# Step 000493, dice_loss 0.0096, rbox_loss 0.0142, total_loss 0.0239
# Step 000494, dice_loss 0.0098, rbox_loss 0.0053, total_loss 0.0151
# Step 000495, dice_loss 0.0095, rbox_loss 0.0154, total_loss 0.0249
# Step 000496, dice_loss 0.0097, rbox_loss 0.0096, total_loss 0.0192
# Step 000497, dice_loss 0.0099, rbox_loss 0.0044, total_loss 0.0143
# Step 000498, dice_loss 0.0098, rbox_loss 0.0106, total_loss 0.0203
# Step 000499, dice_loss 0.0094, rbox_loss 0.0183, total_loss 0.0277
# Step 000500, dice_loss 0.0089, rbox_loss 0.0372, total_loss 0.0461
# global_step : 500, checkpoint is saved!
# Step 000501, dice_loss 0.0093, rbox_loss 0.0173, total_loss 0.0265
# Step 000502, dice_loss 0.0091, rbox_loss 0.0290, total_loss 0.0381
# Step 000503, dice_loss 0.0096, rbox_loss 0.0130, total_loss 0.0226
# Step 000504, dice_loss 0.0097, rbox_loss 0.0083, total_loss 0.0179
# Step 000505, dice_loss 0.0095, rbox_loss 0.0108, total_loss 0.0203
# Step 000506, dice_loss 0.0099, rbox_loss 0.0016, total_loss 0.0115
# Step 000507, dice_loss 0.0089, rbox_loss 0.0316, total_loss 0.0405
# Step 000508, dice_loss 0.0099, rbox_loss 0.0011, total_loss 0.0111
# Step 000509, dice_loss 0.0096, rbox_loss 0.0099, total_loss 0.0195
# Step 000510, dice_loss 0.0088, rbox_loss 0.0310, total_loss 0.0398
# Step 000511, dice_loss 0.0090, rbox_loss 0.0261, total_loss 0.0351
# Step 000512, dice_loss 0.0100, rbox_loss 0.0023, total_loss 0.0122
# Step 000513, dice_loss 0.0095, rbox_loss 0.0161, total_loss 0.0256
# Step 000514, dice_loss 0.0097, rbox_loss 0.0106, total_loss 0.0202
# Step 000515, dice_loss 0.0098, rbox_loss 0.0064, total_loss 0.0162
# Step 000516, dice_loss 0.0089, rbox_loss 0.0343, total_loss 0.0433
# Step 000517, dice_loss 0.0095, rbox_loss 0.0127, total_loss 0.0223
# Step 000518, dice_loss 0.0095, rbox_loss 0.0145, total_loss 0.0240
# Step 000519, dice_loss 0.0089, rbox_loss 0.0321, total_loss 0.0410
# Step 000520, dice_loss 0.0081, rbox_loss 0.0548, total_loss 0.0629
# Step 000521, dice_loss 0.0097, rbox_loss 0.0087, total_loss 0.0184
# Step 000522, dice_loss 0.0089, rbox_loss 0.0389, total_loss 0.0478
# Step 000523, dice_loss 0.0092, rbox_loss 0.0284, total_loss 0.0376
# Step 000524, dice_loss 0.0093, rbox_loss 0.0166, total_loss 0.0259
# Step 000525, dice_loss 0.0091, rbox_loss 0.0356, total_loss 0.0447
# Step 000526, dice_loss 0.0093, rbox_loss 0.0201, total_loss 0.0295
# Step 000527, dice_loss 0.0093, rbox_loss 0.0174, total_loss 0.0267
# Step 000528, dice_loss 0.0094, rbox_loss 0.0121, total_loss 0.0216
# Step 000529, dice_loss 0.0097, rbox_loss 0.0062, total_loss 0.0158
# Step 000530, dice_loss 0.0090, rbox_loss 0.0221, total_loss 0.0311
# Step 000531, dice_loss 0.0091, rbox_loss 0.0227, total_loss 0.0318
# Step 000532, dice_loss 0.0094, rbox_loss 0.0144, total_loss 0.0238
# Step 000533, dice_loss 0.0097, rbox_loss 0.0084, total_loss 0.0181
# Step 000534, dice_loss 0.0091, rbox_loss 0.0157, total_loss 0.0249
# Step 000535, dice_loss 0.0093, rbox_loss 0.0123, total_loss 0.0217
# Step 000536, dice_loss 0.0088, rbox_loss 0.0262, total_loss 0.0350
# Step 000537, dice_loss 0.0094, rbox_loss 0.0152, total_loss 0.0246
# Step 000538, dice_loss 0.0096, rbox_loss 0.0084, total_loss 0.0180
# Step 000539, dice_loss 0.0090, rbox_loss 0.0321, total_loss 0.0411
# Step 000540, dice_loss 0.0083, rbox_loss 0.0498, total_loss 0.0581
# Step 000541, dice_loss 0.0093, rbox_loss 0.0162, total_loss 0.0256
# Step 000542, dice_loss 0.0088, rbox_loss 0.0251, total_loss 0.0338
# Step 000543, dice_loss 0.0096, rbox_loss 0.0129, total_loss 0.0224
# Step 000544, dice_loss 0.0093, rbox_loss 0.0167, total_loss 0.0261
# Step 000545, dice_loss 0.0098, rbox_loss 0.0123, total_loss 0.0221
# Step 000546, dice_loss 0.0085, rbox_loss 0.0378, total_loss 0.0463
# Step 000547, dice_loss 0.0092, rbox_loss 0.0199, total_loss 0.0291
# Step 000548, dice_loss 0.0096, rbox_loss 0.0109, total_loss 0.0205
# Step 000549, dice_loss 0.0099, rbox_loss 0.0035, total_loss 0.0134
# Step 000550, dice_loss 0.0098, rbox_loss 0.0032, total_loss 0.0130
# Step 000551, dice_loss 0.0092, rbox_loss 0.0150, total_loss 0.0242
# Step 000552, dice_loss 0.0094, rbox_loss 0.0123, total_loss 0.0217
# Step 000553, dice_loss 0.0096, rbox_loss 0.0115, total_loss 0.0211
# Step 000554, dice_loss 0.0088, rbox_loss 0.0254, total_loss 0.0342
# Step 000555, dice_loss 0.0099, rbox_loss 0.0031, total_loss 0.0130
# Step 000556, dice_loss 0.0099, rbox_loss 0.0016, total_loss 0.0115
# Step 000557, dice_loss 0.0092, rbox_loss 0.0107, total_loss 0.0199
# Step 000558, dice_loss 0.0091, rbox_loss 0.0166, total_loss 0.0258
# Step 000559, dice_loss 0.0085, rbox_loss 0.0297, total_loss 0.0382
# Step 000560, dice_loss 0.0096, rbox_loss 0.0057, total_loss 0.0153
# Step 000561, dice_loss 0.0090, rbox_loss 0.0165, total_loss 0.0255
# Step 000562, dice_loss 0.0082, rbox_loss 0.0312, total_loss 0.0394
# Step 000563, dice_loss 0.0094, rbox_loss 0.0087, total_loss 0.0181
# Step 000564, dice_loss 0.0088, rbox_loss 0.0281, total_loss 0.0369
# Step 000565, dice_loss 0.0093, rbox_loss 0.0107, total_loss 0.0201
# Step 000566, dice_loss 0.0085, rbox_loss 0.0225, total_loss 0.0310
# Step 000567, dice_loss 0.0088, rbox_loss 0.0187, total_loss 0.0275
# Step 000568, dice_loss 0.0092, rbox_loss 0.0119, total_loss 0.0212
# Step 000569, dice_loss 0.0085, rbox_loss 0.0251, total_loss 0.0335
# Step 000570, dice_loss 0.0098, rbox_loss 0.0032, total_loss 0.0130
# Step 000571, dice_loss 0.0092, rbox_loss 0.0117, total_loss 0.0209
# Step 000572, dice_loss 0.0096, rbox_loss 0.0120, total_loss 0.0216
# Step 000573, dice_loss 0.0090, rbox_loss 0.0122, total_loss 0.0212
# Step 000574, dice_loss 0.0090, rbox_loss 0.0191, total_loss 0.0281
# Step 000575, dice_loss 0.0095, rbox_loss 0.0048, total_loss 0.0142
# Step 000576, dice_loss 0.0094, rbox_loss 0.0104, total_loss 0.0198
# Step 000577, dice_loss 0.0096, rbox_loss 0.0058, total_loss 0.0155
# Step 000578, dice_loss 0.0084, rbox_loss 0.0237, total_loss 0.0322
# Step 000579, dice_loss 0.0094, rbox_loss 0.0083, total_loss 0.0176
# Step 000580, dice_loss 0.0094, rbox_loss 0.0112, total_loss 0.0206
# Step 000581, dice_loss 0.0093, rbox_loss 0.0194, total_loss 0.0288
# Step 000582, dice_loss 0.0094, rbox_loss 0.0086, total_loss 0.0180
# Step 000583, dice_loss 0.0088, rbox_loss 0.0190, total_loss 0.0277
# Step 000584, dice_loss 0.0092, rbox_loss 0.0131, total_loss 0.0223
# Step 000585, dice_loss 0.0086, rbox_loss 0.0248, total_loss 0.0334
# Step 000586, dice_loss 0.0091, rbox_loss 0.0109, total_loss 0.0200
# Step 000587, dice_loss 0.0096, rbox_loss 0.0059, total_loss 0.0155
# Step 000588, dice_loss 0.0086, rbox_loss 0.0199, total_loss 0.0285
# Step 000589, dice_loss 0.0091, rbox_loss 0.0124, total_loss 0.0215
# Step 000590, dice_loss 0.0078, rbox_loss 0.0343, total_loss 0.0421
# Step 000591, dice_loss 0.0095, rbox_loss 0.0049, total_loss 0.0144
# Step 000592, dice_loss 0.0091, rbox_loss 0.0144, total_loss 0.0234
# Step 000593, dice_loss 0.0097, rbox_loss 0.0037, total_loss 0.0135
# Step 000594, dice_loss 0.0097, rbox_loss 0.0041, total_loss 0.0138
# Step 000595, dice_loss 0.0089, rbox_loss 0.0334, total_loss 0.0423
# Step 000596, dice_loss 0.0084, rbox_loss 0.0262, total_loss 0.0345
# Step 000597, dice_loss 0.0080, rbox_loss 0.0359, total_loss 0.0439
# Step 000598, dice_loss 0.0084, rbox_loss 0.0179, total_loss 0.0264
# Step 000599, dice_loss 0.0077, rbox_loss 0.0324, total_loss 0.0401
# Step 000600, dice_loss 0.0090, rbox_loss 0.0123, total_loss 0.0213
# global_step : 600, checkpoint is saved!
# Step 000601, dice_loss 0.0085, rbox_loss 0.0195, total_loss 0.0279
# Step 000602, dice_loss 0.0086, rbox_loss 0.0226, total_loss 0.0312
# Step 000603, dice_loss 0.0079, rbox_loss 0.0435, total_loss 0.0513
# Step 000604, dice_loss 0.0090, rbox_loss 0.0236, total_loss 0.0326
# Step 000605, dice_loss 0.0085, rbox_loss 0.0343, total_loss 0.0427
# Step 000606, dice_loss 0.0088, rbox_loss 0.0211, total_loss 0.0299
# Step 000607, dice_loss 0.0092, rbox_loss 0.0104, total_loss 0.0196
# Step 000608, dice_loss 0.0094, rbox_loss 0.0115, total_loss 0.0209
# Step 000609, dice_loss 0.0089, rbox_loss 0.0134, total_loss 0.0223
# Step 000610, dice_loss 0.0089, rbox_loss 0.0160, total_loss 0.0249
# Step 000611, dice_loss 0.0090, rbox_loss 0.0112, total_loss 0.0202
# Step 000612, dice_loss 0.0092, rbox_loss 0.0142, total_loss 0.0234
# Step 000613, dice_loss 0.0098, rbox_loss 0.0039, total_loss 0.0137
# Step 000614, dice_loss 0.0092, rbox_loss 0.0099, total_loss 0.0192
# Step 000615, dice_loss 0.0096, rbox_loss 0.0047, total_loss 0.0143
# Step 000616, dice_loss 0.0079, rbox_loss 0.0353, total_loss 0.0432
# Step 000617, dice_loss 0.0083, rbox_loss 0.0271, total_loss 0.0353
# Step 000618, dice_loss 0.0096, rbox_loss 0.0107, total_loss 0.0202
# Step 000619, dice_loss 0.0092, rbox_loss 0.0165, total_loss 0.0257
# Step 000620, dice_loss 0.0085, rbox_loss 0.0308, total_loss 0.0393
# Step 000621, dice_loss 0.0085, rbox_loss 0.0213, total_loss 0.0298
# Step 000622, dice_loss 0.0089, rbox_loss 0.0183, total_loss 0.0273
# Step 000623, dice_loss 0.0097, rbox_loss 0.0059, total_loss 0.0156
# Step 000624, dice_loss 0.0095, rbox_loss 0.0085, total_loss 0.0180
# Step 000625, dice_loss 0.0073, rbox_loss 0.0374, total_loss 0.0447
# Step 000626, dice_loss 0.0076, rbox_loss 0.0178, total_loss 0.0253
# Step 000627, dice_loss 0.0086, rbox_loss 0.0116, total_loss 0.0202
# Step 000628, dice_loss 0.0077, rbox_loss 0.0183, total_loss 0.0260
# Step 000629, dice_loss 0.0087, rbox_loss 0.0086, total_loss 0.0173
# Step 000630, dice_loss 0.0080, rbox_loss 0.0142, total_loss 0.0222
# Step 000631, dice_loss 0.0094, rbox_loss 0.0059, total_loss 0.0153
# Step 000632, dice_loss 0.0097, rbox_loss 0.0053, total_loss 0.0150
# Step 000633, dice_loss 0.0076, rbox_loss 0.0284, total_loss 0.0360
# Step 000634, dice_loss 0.0080, rbox_loss 0.0227, total_loss 0.0307
# Step 000635, dice_loss 0.0069, rbox_loss 0.0265, total_loss 0.0334
# Step 000636, dice_loss 0.0096, rbox_loss 0.0029, total_loss 0.0125
# Step 000637, dice_loss 0.0068, rbox_loss 0.0251, total_loss 0.0319
# Step 000638, dice_loss 0.0094, rbox_loss 0.0027, total_loss 0.0122
# Step 000639, dice_loss 0.0075, rbox_loss 0.0154, total_loss 0.0229
# Step 000640, dice_loss 0.0089, rbox_loss 0.0052, total_loss 0.0142
# Step 000641, dice_loss 0.0061, rbox_loss 0.0238, total_loss 0.0299
# Step 000642, dice_loss 0.0091, rbox_loss 0.0041, total_loss 0.0131
# Step 000643, dice_loss 0.0076, rbox_loss 0.0128, total_loss 0.0204
# Step 000644, dice_loss 0.0084, rbox_loss 0.0206, total_loss 0.0289
# Step 000645, dice_loss 0.0079, rbox_loss 0.0177, total_loss 0.0256
# Step 000646, dice_loss 0.0090, rbox_loss 0.0097, total_loss 0.0187
# Step 000647, dice_loss 0.0083, rbox_loss 0.0150, total_loss 0.0233
# Step 000648, dice_loss 0.0083, rbox_loss 0.0117, total_loss 0.0200
# Step 000649, dice_loss 0.0081, rbox_loss 0.0185, total_loss 0.0266
# Step 000650, dice_loss 0.0091, rbox_loss 0.0092, total_loss 0.0183
# Step 000651, dice_loss 0.0075, rbox_loss 0.0246, total_loss 0.0321
# Step 000652, dice_loss 0.0079, rbox_loss 0.0153, total_loss 0.0233
# Step 000653, dice_loss 0.0071, rbox_loss 0.0167, total_loss 0.0238
# Step 000654, dice_loss 0.0091, rbox_loss 0.0080, total_loss 0.0172
# Step 000655, dice_loss 0.0078, rbox_loss 0.0178, total_loss 0.0256
# Step 000656, dice_loss 0.0065, rbox_loss 0.0308, total_loss 0.0372
# Step 000657, dice_loss 0.0093, rbox_loss 0.0050, total_loss 0.0143
# Step 000658, dice_loss 0.0083, rbox_loss 0.0081, total_loss 0.0164
# Step 000659, dice_loss 0.0075, rbox_loss 0.0154, total_loss 0.0229
# Step 000660, dice_loss 0.0081, rbox_loss 0.0143, total_loss 0.0224
# Step 000661, dice_loss 0.0070, rbox_loss 0.0208, total_loss 0.0278
# Step 000662, dice_loss 0.0093, rbox_loss 0.0024, total_loss 0.0118
# Step 000663, dice_loss 0.0090, rbox_loss 0.0025, total_loss 0.0115
# Step 000664, dice_loss 0.0065, rbox_loss 0.0220, total_loss 0.0285
# Step 000665, dice_loss 0.0072, rbox_loss 0.0201, total_loss 0.0273
# Step 000666, dice_loss 0.0071, rbox_loss 0.0124, total_loss 0.0194
# Step 000667, dice_loss 0.0084, rbox_loss 0.0080, total_loss 0.0164
# Step 000668, dice_loss 0.0046, rbox_loss 0.0275, total_loss 0.0321
# Step 000669, dice_loss 0.0083, rbox_loss 0.0039, total_loss 0.0121
# Step 000670, dice_loss 0.0089, rbox_loss 0.0053, total_loss 0.0142
# Step 000671, dice_loss 0.0084, rbox_loss 0.0059, total_loss 0.0143
# Step 000672, dice_loss 0.0077, rbox_loss 0.0067, total_loss 0.0144
# Step 000673, dice_loss 0.0071, rbox_loss 0.0094, total_loss 0.0165
# Step 000674, dice_loss 0.0056, rbox_loss 0.0218, total_loss 0.0274
# Step 000675, dice_loss 0.0051, rbox_loss 0.0211, total_loss 0.0262
# Step 000676, dice_loss 0.0077, rbox_loss 0.0063, total_loss 0.0140
# Step 000677, dice_loss 0.0050, rbox_loss 0.0267, total_loss 0.0317
# Step 000678, dice_loss 0.0085, rbox_loss 0.0059, total_loss 0.0144
# Step 000679, dice_loss 0.0061, rbox_loss 0.0140, total_loss 0.0202
# Step 000680, dice_loss 0.0070, rbox_loss 0.0084, total_loss 0.0154
# Step 000681, dice_loss 0.0090, rbox_loss 0.0038, total_loss 0.0128
# Step 000682, dice_loss 0.0077, rbox_loss 0.0113, total_loss 0.0191
# Step 000683, dice_loss 0.0056, rbox_loss 0.0237, total_loss 0.0294
# Step 000684, dice_loss 0.0059, rbox_loss 0.0356, total_loss 0.0415
# Step 000685, dice_loss 0.0088, rbox_loss 0.0169, total_loss 0.0256
# Step 000686, dice_loss 0.0093, rbox_loss 0.0076, total_loss 0.0169
# Step 000687, dice_loss 0.0088, rbox_loss 0.0127, total_loss 0.0215
# Step 000688, dice_loss 0.0067, rbox_loss 0.0374, total_loss 0.0442
# Step 000689, dice_loss 0.0081, rbox_loss 0.0196, total_loss 0.0277
# Step 000690, dice_loss 0.0077, rbox_loss 0.0251, total_loss 0.0328
# Step 000691, dice_loss 0.0086, rbox_loss 0.0094, total_loss 0.0180
# Step 000692, dice_loss 0.0091, rbox_loss 0.0032, total_loss 0.0124
# Step 000693, dice_loss 0.0093, rbox_loss 0.0044, total_loss 0.0136
# Step 000694, dice_loss 0.0089, rbox_loss 0.0076, total_loss 0.0165
# Step 000695, dice_loss 0.0089, rbox_loss 0.0045, total_loss 0.0134
# Step 000696, dice_loss 0.0071, rbox_loss 0.0232, total_loss 0.0303
# Step 000697, dice_loss 0.0070, rbox_loss 0.0170, total_loss 0.0241
# Step 000698, dice_loss 0.0093, rbox_loss 0.0069, total_loss 0.0162
# Step 000699, dice_loss 0.0072, rbox_loss 0.0330, total_loss 0.0402
# Step 000700, dice_loss 0.0096, rbox_loss 0.0060, total_loss 0.0156
# global_step : 700, checkpoint is saved!
# Step 000701, dice_loss 0.0095, rbox_loss 0.0040, total_loss 0.0135
# Step 000702, dice_loss 0.0084, rbox_loss 0.0073, total_loss 0.0157
# Step 000703, dice_loss 0.0097, rbox_loss 0.0021, total_loss 0.0118
# Step 000704, dice_loss 0.0071, rbox_loss 0.0163, total_loss 0.0234
# Step 000705, dice_loss 0.0081, rbox_loss 0.0105, total_loss 0.0185
# Step 000706, dice_loss 0.0085, rbox_loss 0.0151, total_loss 0.0235
# ...
# Step 002207, dice_loss 0.0007, rbox_loss 0.0087, total_loss 0.0094
# Step 002208, dice_loss 0.0011, rbox_loss 0.0120, total_loss 0.0131
# Step 002209, dice_loss 0.0022, rbox_loss 0.0063, total_loss 0.0084
# Step 002210, dice_loss 0.0030, rbox_loss 0.0012, total_loss 0.0042
# Step 002211, dice_loss 0.0016, rbox_loss 0.0122, total_loss 0.0138
# Step 002212, dice_loss 0.0018, rbox_loss 0.0129, total_loss 0.0148
# Step 002213, dice_loss 0.0016, rbox_loss 0.0052, total_loss 0.0068
# Step 002214, dice_loss 0.0035, rbox_loss 0.0054, total_loss 0.0089
# Step 002215, dice_loss 0.0010, rbox_loss 0.0191, total_loss 0.0201
# Step 002216, dice_loss 0.0035, rbox_loss 0.0016, total_loss 0.0051
# Step 002217, dice_loss 0.0007, rbox_loss 0.0276, total_loss 0.0283
# Step 002218, dice_loss 0.0014, rbox_loss 0.0041, total_loss 0.0056
# Step 002219, dice_loss 0.0012, rbox_loss 0.0067, total_loss 0.0079
# Step 002220, dice_loss 0.0012, rbox_loss 0.0038, total_loss 0.0050
# Step 002221, dice_loss 0.0031, rbox_loss 0.0028, total_loss 0.0058
# Step 002222, dice_loss 0.0009, rbox_loss 0.0173, total_loss 0.0183
# Step 002223, dice_loss 0.0019, rbox_loss 0.0111, total_loss 0.0130
# Step 002224, dice_loss 0.0085, rbox_loss 0.0119, total_loss 0.0205
# Step 002225, dice_loss 0.0022, rbox_loss 0.0027, total_loss 0.0049
# Step 002226, dice_loss 0.0080, rbox_loss 0.0113, total_loss 0.0193
# Step 002227, dice_loss 0.0013, rbox_loss 0.0108, total_loss 0.0120
# Step 002228, dice_loss 0.0025, rbox_loss 0.0140, total_loss 0.0165
# Step 002229, dice_loss 0.0004, rbox_loss 0.0138, total_loss 0.0142
# Step 002230, dice_loss 0.0010, rbox_loss 0.0116, total_loss 0.0126
# Step 002231, dice_loss 0.0020, rbox_loss 0.0141, total_loss 0.0161
# Step 002232, dice_loss 0.0018, rbox_loss 0.0174, total_loss 0.0192
# Step 002233, dice_loss 0.0017, rbox_loss 0.0127, total_loss 0.0144
# Step 002234, dice_loss 0.0049, rbox_loss 0.0070, total_loss 0.0118
# Step 002235, dice_loss 0.0015, rbox_loss 0.0102, total_loss 0.0117
# Step 002236, dice_loss 0.0006, rbox_loss 0.0132, total_loss 0.0138
# Step 002237, dice_loss 0.0026, rbox_loss 0.0170, total_loss 0.0195
# Step 002238, dice_loss 0.0007, rbox_loss 0.0152, total_loss 0.0159
# Step 002239, dice_loss 0.0056, rbox_loss 0.0021, total_loss 0.0077
# Step 002240, dice_loss 0.0065, rbox_loss 0.0011, total_loss 0.0076
# Step 002241, dice_loss 0.0033, rbox_loss 0.0030, total_loss 0.0063
# Step 002242, dice_loss 0.0011, rbox_loss 0.0144, total_loss 0.0155
# Step 002243, dice_loss 0.0011, rbox_loss 0.0085, total_loss 0.0096
# Step 002244, dice_loss 0.0017, rbox_loss 0.0124, total_loss 0.0141
# Step 002245, dice_loss 0.0014, rbox_loss 0.0124, total_loss 0.0138
# Step 002246, dice_loss 0.0030, rbox_loss 0.0027, total_loss 0.0058
# Step 002247, dice_loss 0.0021, rbox_loss 0.0060, total_loss 0.0082
# Step 002248, dice_loss 0.0011, rbox_loss 0.0131, total_loss 0.0142
# Step 002249, dice_loss 0.0012, rbox_loss 0.0044, total_loss 0.0056
# Step 002250, dice_loss 0.0039, rbox_loss 0.0029, total_loss 0.0068
# Step 002251, dice_loss 0.0010, rbox_loss 0.0117, total_loss 0.0128
# Step 002252, dice_loss 0.0047, rbox_loss 0.0074, total_loss 0.0122
# Step 002253, dice_loss 0.0014, rbox_loss 0.0128, total_loss 0.0143
# Step 002254, dice_loss 0.0019, rbox_loss 0.0041, total_loss 0.0060
# Step 002255, dice_loss 0.0093, rbox_loss 0.0053, total_loss 0.0146
# Step 002256, dice_loss 0.0009, rbox_loss 0.0051, total_loss 0.0060
# Step 002257, dice_loss 0.0089, rbox_loss 0.0106, total_loss 0.0195
# Step 002258, dice_loss 0.0009, rbox_loss 0.0171, total_loss 0.0180
# Step 002259, dice_loss 0.0066, rbox_loss 0.0035, total_loss 0.0101
# Step 002260, dice_loss 0.0016, rbox_loss 0.0135, total_loss 0.0151
# Step 002261, dice_loss 0.0014, rbox_loss 0.0104, total_loss 0.0118
# Step 002262, dice_loss 0.0034, rbox_loss 0.0030, total_loss 0.0064
# Step 002263, dice_loss 0.0020, rbox_loss 0.0171, total_loss 0.0191
# Step 002264, dice_loss 0.0014, rbox_loss 0.0115, total_loss 0.0129
# Step 002265, dice_loss 0.0025, rbox_loss 0.0033, total_loss 0.0058
# Step 002266, dice_loss 0.0014, rbox_loss 0.0035, total_loss 0.0049
# Step 002267, dice_loss 0.0016, rbox_loss 0.0133, total_loss 0.0149
# Step 002268, dice_loss 0.0028, rbox_loss 0.0147, total_loss 0.0175
# Step 002269, dice_loss 0.0020, rbox_loss 0.0090, total_loss 0.0110
# Step 002270, dice_loss 0.0022, rbox_loss 0.0176, total_loss 0.0198
# Step 002271, dice_loss 0.0009, rbox_loss 0.0079, total_loss 0.0088
# Step 002272, dice_loss 0.0046, rbox_loss 0.0024, total_loss 0.0070
# Step 002273, dice_loss 0.0021, rbox_loss 0.0053, total_loss 0.0074
# Step 002274, dice_loss 0.0010, rbox_loss 0.0146, total_loss 0.0157
# Step 002275, dice_loss 0.0010, rbox_loss 0.0077, total_loss 0.0087
# Step 002276, dice_loss 0.0020, rbox_loss 0.0279, total_loss 0.0299
# invalid poly
# Step 002277, dice_loss 0.0017, rbox_loss 0.0068, total_loss 0.0086
# Step 002278, dice_loss 0.0038, rbox_loss 0.0034, total_loss 0.0072
# Step 002279, dice_loss 0.0042, rbox_loss 0.0150, total_loss 0.0191
# Step 002280, dice_loss 0.0018, rbox_loss 0.0171, total_loss 0.0189
# Step 002281, dice_loss 0.0032, rbox_loss 0.0120, total_loss 0.0152
# Step 002282, dice_loss 0.0012, rbox_loss 0.0066, total_loss 0.0078
# Step 002283, dice_loss 0.0043, rbox_loss 0.0012, total_loss 0.0055
# Step 002284, dice_loss 0.0019, rbox_loss 0.0064, total_loss 0.0083
# Step 002285, dice_loss 0.0016, rbox_loss 0.0140, total_loss 0.0156
# Step 002286, dice_loss 0.0024, rbox_loss 0.0073, total_loss 0.0097
# Step 002287, dice_loss 0.0016, rbox_loss 0.0088, total_loss 0.0104
# Step 002288, dice_loss 0.0012, rbox_loss 0.0069, total_loss 0.0081
# Step 002289, dice_loss 0.0017, rbox_loss 0.0077, total_loss 0.0094
# Step 002290, dice_loss 0.0050, rbox_loss 0.0007, total_loss 0.0057
# Step 002291, dice_loss 0.0017, rbox_loss 0.0130, total_loss 0.0147
# Step 002292, dice_loss 0.0025, rbox_loss 0.0057, total_loss 0.0082
# Step 002293, dice_loss 0.0019, rbox_loss 0.0134, total_loss 0.0153
# Step 002294, dice_loss 0.0016, rbox_loss 0.0099, total_loss 0.0115
# Step 002295, dice_loss 0.0008, rbox_loss 0.0125, total_loss 0.0133
# Step 002296, dice_loss 0.0007, rbox_loss 0.0113, total_loss 0.0120
# Step 002297, dice_loss 0.0015, rbox_loss 0.0026, total_loss 0.0041
# Step 002298, dice_loss 0.0023, rbox_loss 0.0045, total_loss 0.0068
# Step 002299, dice_loss 0.0017, rbox_loss 0.0147, total_loss 0.0164
# Step 002300, dice_loss 0.0015, rbox_loss 0.0131, total_loss 0.0147
# global_step : 2300, checkpoint is saved!
# Step 002301, dice_loss 0.0015, rbox_loss 0.0145, total_loss 0.0160
# Step 002302, dice_loss 0.0028, rbox_loss 0.0044, total_loss 0.0071
# Step 002303, dice_loss 0.0026, rbox_loss 0.0072, total_loss 0.0098
# Step 002304, dice_loss 0.0019, rbox_loss 0.0129, total_loss 0.0147
# Step 002305, dice_loss 0.0019, rbox_loss 0.0089, total_loss 0.0107
# Step 002306, dice_loss 0.0071, rbox_loss 0.0020, total_loss 0.0091
# Step 002307, dice_loss 0.0014, rbox_loss 0.0168, total_loss 0.0182
# Step 002308, dice_loss 0.0009, rbox_loss 0.0070, total_loss 0.0079
# Step 002309, dice_loss 0.0009, rbox_loss 0.0161, total_loss 0.0171
# Step 002310, dice_loss 0.0015, rbox_loss 0.0109, total_loss 0.0124
# Step 002311, dice_loss 0.0023, rbox_loss 0.0173, total_loss 0.0196
# Step 002312, dice_loss 0.0012, rbox_loss 0.0049, total_loss 0.0061
# Step 002313, dice_loss 0.0040, rbox_loss 0.0031, total_loss 0.0071
# Step 002314, dice_loss 0.0015, rbox_loss 0.0134, total_loss 0.0149
# Step 002315, dice_loss 0.0015, rbox_loss 0.0051, total_loss 0.0066
# Step 002316, dice_loss 0.0060, rbox_loss 0.0036, total_loss 0.0096
# Step 002317, dice_loss 0.0009, rbox_loss 0.0107, total_loss 0.0116
# Step 002318, dice_loss 0.0021, rbox_loss 0.0049, total_loss 0.0070
# Step 002319, dice_loss 0.0017, rbox_loss 0.0165, total_loss 0.0182
# Step 002320, dice_loss 0.0043, rbox_loss 0.0038, total_loss 0.0082
# Step 002321, dice_loss 0.0048, rbox_loss 0.0041, total_loss 0.0089
# Step 002322, dice_loss 0.0018, rbox_loss 0.0095, total_loss 0.0113
# Step 002323, dice_loss 0.0014, rbox_loss 0.0146, total_loss 0.0159
# Step 002324, dice_loss 0.0023, rbox_loss 0.0154, total_loss 0.0177
# Step 002325, dice_loss 0.0006, rbox_loss 0.0122, total_loss 0.0128
# Step 002326, dice_loss 0.0020, rbox_loss 0.0099, total_loss 0.0119
# Step 002327, dice_loss 0.0023, rbox_loss 0.0042, total_loss 0.0066
# Step 002328, dice_loss 0.0014, rbox_loss 0.0110, total_loss 0.0125
# Step 002329, dice_loss 0.0023, rbox_loss 0.0047, total_loss 0.0070
# Step 002330, dice_loss 0.0012, rbox_loss 0.0060, total_loss 0.0072
# Step 002331, dice_loss 0.0020, rbox_loss 0.0040, total_loss 0.0060
# Step 002332, dice_loss 0.0011, rbox_loss 0.0070, total_loss 0.0081
# Step 002333, dice_loss 0.0020, rbox_loss 0.0083, total_loss 0.0103
# Step 002334, dice_loss 0.0052, rbox_loss 0.0145, total_loss 0.0196
# Step 002335, dice_loss 0.0017, rbox_loss 0.0121, total_loss 0.0139
# Step 002336, dice_loss 0.0019, rbox_loss 0.0054, total_loss 0.0073
# Step 002337, dice_loss 0.0017, rbox_loss 0.0112, total_loss 0.0129
# Step 002338, dice_loss 0.0032, rbox_loss 0.0121, total_loss 0.0153
# Step 002339, dice_loss 0.0010, rbox_loss 0.0088, total_loss 0.0098
# Step 002340, dice_loss 0.0014, rbox_loss 0.0063, total_loss 0.0077
# Step 002341, dice_loss 0.0064, rbox_loss 0.0050, total_loss 0.0113
# Step 002342, dice_loss 0.0016, rbox_loss 0.0092, total_loss 0.0108
# Step 002343, dice_loss 0.0036, rbox_loss 0.0044, total_loss 0.0080
# Step 002344, dice_loss 0.0014, rbox_loss 0.0144, total_loss 0.0158
# Step 002345, dice_loss 0.0024, rbox_loss 0.0128, total_loss 0.0152
# Step 002346, dice_loss 0.0009, rbox_loss 0.0161, total_loss 0.0171
# Step 002347, dice_loss 0.0022, rbox_loss 0.0095, total_loss 0.0118
# Step 002348, dice_loss 0.0031, rbox_loss 0.0090, total_loss 0.0121
# Step 002349, dice_loss 0.0009, rbox_loss 0.0198, total_loss 0.0206
# Step 002350, dice_loss 0.0011, rbox_loss 0.0164, total_loss 0.0175
# Step 002351, dice_loss 0.0012, rbox_loss 0.0080, total_loss 0.0092
# Step 002352, dice_loss 0.0020, rbox_loss 0.0116, total_loss 0.0136
# Step 002353, dice_loss 0.0020, rbox_loss 0.0077, total_loss 0.0096
# Step 002354, dice_loss 0.0059, rbox_loss 0.0021, total_loss 0.0080
# Step 002355, dice_loss 0.0039, rbox_loss 0.0041, total_loss 0.0081
# Step 002356, dice_loss 0.0014, rbox_loss 0.0159, total_loss 0.0173
# Step 002357, dice_loss 0.0047, rbox_loss 0.0005, total_loss 0.0052
# Step 002358, dice_loss 0.0022, rbox_loss 0.0070, total_loss 0.0091
# Step 002359, dice_loss 0.0013, rbox_loss 0.0177, total_loss 0.0190
# Step 002360, dice_loss 0.0027, rbox_loss 0.0041, total_loss 0.0069
# Step 002361, dice_loss 0.0011, rbox_loss 0.0077, total_loss 0.0087
# Step 002362, dice_loss 0.0008, rbox_loss 0.0123, total_loss 0.0131
# Step 002363, dice_loss 0.0010, rbox_loss 0.0113, total_loss 0.0123
# Step 002364, dice_loss 0.0005, rbox_loss 0.0117, total_loss 0.0122
# Step 002365, dice_loss 0.0007, rbox_loss 0.0071, total_loss 0.0078
# Step 002366, dice_loss 0.0015, rbox_loss 0.0102, total_loss 0.0117
# Step 002367, dice_loss 0.0010, rbox_loss 0.0166, total_loss 0.0176
# Step 002368, dice_loss 0.0025, rbox_loss 0.0086, total_loss 0.0111
# Step 002369, dice_loss 0.0010, rbox_loss 0.0136, total_loss 0.0145
# Step 002370, dice_loss 0.0034, rbox_loss 0.0099, total_loss 0.0133
# Step 002371, dice_loss 0.0019, rbox_loss 0.0076, total_loss 0.0095
# Step 002372, dice_loss 0.0021, rbox_loss 0.0029, total_loss 0.0051
# Step 002373, dice_loss 0.0008, rbox_loss 0.0072, total_loss 0.0080
# Step 002374, dice_loss 0.0020, rbox_loss 0.0120, total_loss 0.0140
# Step 002375, dice_loss 0.0012, rbox_loss 0.0126, total_loss 0.0138
# Step 002376, dice_loss 0.0011, rbox_loss 0.0064, total_loss 0.0075
# Step 002377, dice_loss 0.0023, rbox_loss 0.0045, total_loss 0.0068
# Step 002378, dice_loss 0.0013, rbox_loss 0.0065, total_loss 0.0078
# Step 002379, dice_loss 0.0026, rbox_loss 0.0177, total_loss 0.0203
# Step 002380, dice_loss 0.0044, rbox_loss 0.0035, total_loss 0.0079
# Step 002381, dice_loss 0.0009, rbox_loss 0.0012, total_loss 0.0021
# Step 002382, dice_loss 0.0016, rbox_loss 0.0089, total_loss 0.0105
# Step 002383, dice_loss 0.0012, rbox_loss 0.0110, total_loss 0.0122
# Step 002384, dice_loss 0.0019, rbox_loss 0.0196, total_loss 0.0215
# Step 002385, dice_loss 0.0015, rbox_loss 0.0028, total_loss 0.0043
# Step 002386, dice_loss 0.0018, rbox_loss 0.0077, total_loss 0.0095
# Step 002387, dice_loss 0.0013, rbox_loss 0.0188, total_loss 0.0201
# Step 002388, dice_loss 0.0039, rbox_loss 0.0123, total_loss 0.0162
# Step 002389, dice_loss 0.0048, rbox_loss 0.0121, total_loss 0.0170
# Step 002390, dice_loss 0.0015, rbox_loss 0.0143, total_loss 0.0158
# Step 002391, dice_loss 0.0019, rbox_loss 0.0100, total_loss 0.0119
# Step 002392, dice_loss 0.0023, rbox_loss 0.0078, total_loss 0.0101
# Step 002393, dice_loss 0.0007, rbox_loss 0.0240, total_loss 0.0247
# Step 002394, dice_loss 0.0042, rbox_loss 0.0034, total_loss 0.0075
# Step 002395, dice_loss 0.0016, rbox_loss 0.0064, total_loss 0.0080
# Step 002396, dice_loss 0.0021, rbox_loss 0.0098, total_loss 0.0118
# Step 002397, dice_loss 0.0024, rbox_loss 0.0116, total_loss 0.0140
# Step 002398, dice_loss 0.0015, rbox_loss 0.0098, total_loss 0.0113
# Step 002399, dice_loss 0.0015, rbox_loss 0.0105, total_loss 0.0119
# Step 002400, dice_loss 0.0016, rbox_loss 0.0178, total_loss 0.0194
# global_step : 2400, checkpoint is saved!
# Step 002401, dice_loss 0.0007, rbox_loss 0.0087, total_loss 0.0095
# Step 002402, dice_loss 0.0062, rbox_loss 0.0012, total_loss 0.0074
# Step 002403, dice_loss 0.0013, rbox_loss 0.0053, total_loss 0.0066
# Step 002404, dice_loss 0.0010, rbox_loss 0.0111, total_loss 0.0122
# Step 002405, dice_loss 0.0027, rbox_loss 0.0136, total_loss 0.0163
# Step 002406, dice_loss 0.0026, rbox_loss 0.0136, total_loss 0.0162
# Step 002407, dice_loss 0.0013, rbox_loss 0.0082, total_loss 0.0095
# Step 002408, dice_loss 0.0031, rbox_loss 0.0056, total_loss 0.0086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 6
#       1 max_steps = 12000
#       3 while int(ckpt.step) < (max_steps + 1):
#       4     # load data
#       5     [input_images, overly_small_text_region_training_masks, text_region_boundary_training_masks, score_maps], \
# ----> 6     [target_score_maps, target_geo_maps] = next(train_data_generator)
#       8     # update parameter
#       9     train_step(east,
#      10                 input_images,
#      11                 optimizers,
#    (...)
#      17                 score_map_loss_weight
#      18                 )
#
# Cell In[6], line 14, in threadsafe_iter.__next__(self)
#      12 def __next__(self): # Python 3
#      13   with self.lock:
# ---> 14     return next(self.it)
#
# Cell In[6], line 129, in generator(training_data_path, batch_size, input_size, background_ratio, is_train, random_scale, geometry, suppress_warnings, vis, idx)
#     127     im, text_polys = resize_image(im, text_polys, input_size, shift_h, shift_w)
#     128     new_h, new_w, _ = im.shape
# --> 129     score_map, geo_map, overly_small_text_region_training_mask, text_region_boundary_training_mask = generate_rbox((new_h, new_w), text_polys, text_tags, geometry)
#     131 if vis:
#     132     # Visualization for debugging
#     133     fig, axs = plt.subplots(2, 2, figsize=(8, 8))
#
# Cell In[5], line 575, in generate_rbox(im_size, polys, tags, geometry)
#     573 geo_map[y, x, 0] = point_dist_to_line(p0_rect, p1_rect, point)
#     574 # right
# --> 575 geo_map[y, x, 1] = point_dist_to_line(p1_rect, p2_rect, point)
#     576 # down
#     577 geo_map[y, x, 2] = point_dist_to_line(p2_rect, p3_rect, point)
#
# Cell In[5], line 246, in point_dist_to_line(p1, p2, p3)
#     244 def point_dist_to_line(p1, p2, p3):
#     245   # compute the distance from p3 to p1-p2
# --> 246   return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\numpy\linalg\linalg.py:2511, in norm(x, ord, axis, keepdims)
#    2509     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2510 else:
# -> 2511     sqnorm = x.dot(x)
#    2512 ret = sqrt(sqnorm)
#    2513 if keepdims:
#
# KeyboardInterrupt:

# %%
east.save("text-detection-model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 61). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: text-detection-model\assets
# INFO:tensorflow:Assets written to: text-detection-model\assets

# %% [markdown]
# # Model Testing

# %%
# Load model by using checkpoint

vgg16_east = EAST_model()

ckpt = tf.train.Checkpoint(step=tf.Variable(0), model=vgg16_east)
latest_ckpt = tf.train.latest_checkpoint("../models/east_vgg16_rbox_06-12-23-00")

if latest_ckpt:
    ckpt.restore(latest_ckpt)
    print('global_step : {}, checkpoint is restored!'.format(int(ckpt.step)))
# Out:
# global_step : 2400, checkpoint is restored!

# %%
# This is how you load the model
RESIZE_FACTOR = 2

custom_objects = {"RESIZE_FACTOR": RESIZE_FACTOR, }
vgg16_east = tf.keras.models.load_model("text-detection-model", custom_objects=custom_objects)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
vgg16_east.summary()
# Out:
# Model: "east_model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  east-mobilenetv2 (Functiona  [(None, None, None, 1),  2125414
#  l)                           (None, None, None, 5)]
#
# =================================================================
# Total params: 2,125,414
# Trainable params: 2,092,902
# Non-trainable params: 32,512
# _________________________________________________________________

# %%
import locality_aware_nms as nms_locality

def get_images(test_data_path):
  '''
  find image files in test data path
  :return: list of files found
  '''
  files = []
  exts = ['jpg', 'png', 'jpeg', 'JPG']
  for parent, dirnames, filenames in os.walk(test_data_path):
    for filename in filenames:
      for ext in exts:
        if filename.endswith(ext):
          files.append(os.path.join(parent, filename))
          break
  print('Find {} images'.format(len(files)))
  return files


def resize_image(im, max_side_len=2400):
  '''
  resize image to a size multiple of 32 which is required by the network
  :param im: the resized image
  :param max_side_len: limit of max image size to avoid out of memory in gpu
  :return: the resized image and the resize ratio
  '''
  h, w, _ = im.shape

  # resize_w = w
  # resize_h = h
  resize_h, resize_w = (max_side_len, max_side_len)  # Increase input resolution

  # # limit the max side
  # if max(resize_h, resize_w) > max_side_len:
  #   ratio = float(max_side_len) / resize_h if resize_h > resize_w else float(max_side_len) / resize_w
  # else:
  #   ratio = 1.
  # resize_h = int(resize_h * ratio)
  # resize_w = int(resize_w * ratio)

  # resize_h = resize_h if resize_h % 32 == 0 else (resize_h // 32) * 32
  # resize_w = resize_w if resize_w % 32 == 0 else (resize_w // 32) * 32
  # im = cv2.resize(im, (int(resize_w), int(resize_h)))

  # pad_top = (max_side_len - resize_h) // 2
  # pad_bottom = max_side_len - resize_h - pad_top
  # pad_left = (max_side_len - resize_w) // 2
  # pad_right = max_side_len - resize_w - pad_left

  # # Pad the resized image
  # pad_im = cv2.copyMakeBorder(
  #   im,
  #   pad_top, pad_bottom,
  #   pad_left, pad_right,
  #   borderType=cv2.BORDER_CONSTANT,
  #   value=[0, 0, 0]  # Padding color (black)
  # )

  # ratio_h = resize_h / float(h)
  # ratio_w = resize_w / float(w)
  im = cv2.resize(im, (int(resize_w), int(resize_h)))

  ratio_h = resize_h / float(h)
  ratio_w = resize_w / float(w)

  return im, (ratio_h, ratio_w)


def detect(score_map, geo_map, timer, score_map_thresh=0.8, box_thresh=0.1, nms_thres=0.2):
  '''
  restore text boxes from score map and geo map
  :param score_map:
  :param geo_map:
  :param timer:
  :param score_map_thresh: threshhold for score map
  :param box_thresh: threshhold for boxes
  :param nms_thres: threshold for nms
  :return:
  '''
  if len(score_map.shape) == 4:
    score_map = score_map[0, :, :, 0]
    geo_map = geo_map[0, :, :, ]
  # filter the score map
  xy_text = np.argwhere(score_map > score_map_thresh)
  # sort the text boxes via the y axis
  xy_text = xy_text[np.argsort(xy_text[:, 0])]
  # restore
  start = time.time()
  text_box_restored = restore_rectangle(xy_text[:, ::-1]*4, geo_map[xy_text[:, 0], xy_text[:, 1], :]) # N*4*2
  print('{} text boxes before nms'.format(text_box_restored.shape[0]))
  boxes = np.zeros((text_box_restored.shape[0], 9), dtype=np.float32)
  boxes[:, :8] = text_box_restored.reshape((-1, 8))
  boxes[:, 8] = score_map[xy_text[:, 0], xy_text[:, 1]]
  timer['restore'] = time.time() - start
  # nms part
  start = time.time()
  boxes = nms_locality.nms_locality(boxes.astype(np.float64), nms_thres)
#   boxes = lanms.merge_quadrangle_n9(boxes.astype('float32'), nms_thres)
  timer['nms'] = time.time() - start

  if boxes.shape[0] == 0:
    return None, timer

  # here we filter some low score boxes by the average score map, this is different from the orginal paper
  for i, box in enumerate(boxes):
    mask = np.zeros_like(score_map, dtype=np.uint8)
    cv2.fillPoly(mask, box[:8].reshape((-1, 4, 2)).astype(np.int32) // 4, 1)
    boxes[i, 8] = cv2.mean(score_map, mask)[0]
  boxes = boxes[boxes[:, 8] > box_thresh]

  return boxes, timer


def sort_poly(p):
  min_axis = np.argmin(np.sum(p, axis=1))
  p = p[[min_axis, (min_axis+1)%4, (min_axis+2)%4, (min_axis+3)%4]]
  if abs(p[0, 0] - p[1, 0]) > abs(p[0, 1] - p[1, 1]):
    return p
  else:
    return p[[0, 3, 2, 1]]
  
def sort_bounding_boxes_df(df, row_threshold=10):
    """
    Sort bounding boxes in a DataFrame from top-to-bottom and left-to-right.

    Args:
        df (pd.DataFrame): DataFrame with columns ['x', 'y', 'w', 'h'] representing bounding boxes.
        row_threshold (int): Threshold to determine boxes in the same row.

    Returns:
        pd.DataFrame: Sorted DataFrame.
    """
    # Sort by y to group rows
    df = df.sort_values(by='y', ascending=True).reset_index(drop=True)
    
    # Assign row groups based on y-coordinate
    row_groups = [0]  # First row starts as 0
    current_row = 0
    previous_y = df.loc[0, 'y']

    for i in range(1, len(df)):
        if abs(df.loc[i, 'y'] - previous_y) > row_threshold:
            current_row += 1
        row_groups.append(current_row)
        previous_y = df.loc[i, 'y']
    
    df['row_group'] = row_groups

    # Sort within each row group by x-coordinate
    df = df.sort_values(by=['row_group', 'x']).reset_index(drop=True)

    # Drop the row_group column
    df = df.drop(columns=['row_group'])

    return df

# %%
import pandas as pd

# output_dir = "../results/east-mobilenetv2/val"

# img_list = get_images("../data/nutrition-table/val")

# img_file = '../../datasets/openfoodfacts_nutrition-table-detection/train/0000/00287678_2.jpg'
# img_file = '../../datasets/openfoodfacts_nutrition-table-detection/train/0000/00869256_5.jpg'
# img_file = "../data/nutrition-table/val/0000/20608668_3.jpg"
img_file = "../../datasets/openfoodfacts_nutrition-table-detection/Primer/WhatsApp Image 2024-11-04 at 3.46.18 PM (3).jpeg"

# for img_file in img_list:
img = cv2.imread(img_file)[:, :, ::-1]
start_time = time.time()
img_resized, (ratio_h, ratio_w) = resize_image(img, max_side_len=512)

img_resized = (img_resized / 127.5) - 1

timer = {'net': 0, 'restore': 0, 'nms': 0}
start = time.time()

# feed image into model
score_map, geo_map = vgg16_east.predict(img_resized[np.newaxis, :, :, :])

timer['net'] = time.time() - start

boxes, timer = detect(score_map=score_map, geo_map=geo_map, timer=timer, score_map_thresh=0.5, box_thresh=0.1, nms_thres=0.4)

print('{} : net {:.0f}ms, restore {:.0f}ms, nms {:.0f}ms'.format(
    img_file, timer['net']*1000, timer['restore']*1000, timer['nms']*1000))

if boxes is not None:
    boxes = boxes[:, :8].reshape((-1, 4, 2))
    boxes[:, :, 0] /= ratio_w
    boxes[:, :, 1] /= ratio_h

duration = time.time() - start_time
print('[timing] {}'.format(duration))

data = []

if boxes is not None:
    # res_file = os.path.join(output_dir, '{}.csv'.format(os.path.basename(img_file).split('.')[0]))
    # if not os.path.exists(output_dir):
    #     os.makedirs(output_dir)
    # with open(res_file, 'w') as f:
    for box in boxes:
        # to avoid submitting errors
        box = sort_poly(box.astype(np.int32))
        if np.linalg.norm(box[0] - box[1]) < 5 or np.linalg.norm(box[3]-box[0]) < 5:
            continue
        # f.write('{},{},{},{},{},{},{},{}\r\n'.format(
        # box[0, 0], box[0, 1], box[1, 0], box[1, 1], box[2, 0], box[2, 1], box[3, 0], box[3, 1],
        # ))
        points = box.astype(np.int32).reshape((-1, 1, 2))
        x, y, w, h = cv2.boundingRect(points)
        # boxes.append(box)
        # cv2.polylines(img[:, :, ::-1], [box.astype(np.int32).reshape((-1, 1, 2))], True, color=(0, 255, 0), thickness=1)
        # cv2.polylines(img[:, :, ::-1], [points], True, color=(0, 255, 0), thickness=2)
        cv2.rectangle(img[:, :, ::-1], (x, y), (x + w, y + h), (255, 0, 0), 2)
        # plt.imshow(img[y:y+h, x:x+w, :])
        # plt.show()

        data.append({
            "x": x,
            "y": y,
            "w": w,
            "h": h,
        })

df = pd.DataFrame(data)



if not df.empty:
    df = sort_bounding_boxes_df(df)
    # df.to_csv(res_file, index=False)
# img_path = os.path.join(output_dir, os.path.basename(img_file))
# cv2.imwrite(img_path, img[:, :, ::-1])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 2812 text boxes before nms
# ../../datasets/openfoodfacts_nutrition-table-detection/Primer/WhatsApp Image 2024-11-04 at 3.46.18 PM (3).jpeg : net 458ms, restore 0ms, nms 1009ms
# [timing] 1.4734489917755127

# %%
plt.imshow(img[:, :, :])
